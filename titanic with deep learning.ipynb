# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
scaler = StandardScaler()
import pandas_profiling
from datetime import datetime
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, recall_score, precision_score
from sklearn.model_selection import StratifiedKFold
from imblearn.metrics import geometric_mean_score as geo
from imblearn.metrics import make_index_balanced_accuracy as iba
from sklearn.metrics import roc_curve, auc
from imblearn.metrics import geometric_mean_score, make_index_balanced_accuracy, classification_report_imbalanced
#from pycaret.regression import *
import sqlite3
from sqlite3 import Error
import datetime as dt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import ExtraTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier     
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from sklearn.metrics import confusion_matrix,classification_report  
import plotly.express as px
from sklearn.preprocessing import StandardScaler, RobustScaler,MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.cluster import KMeans
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, AveragePooling2D, Flatten, Dropout, BatchNormalization, Activation
from keras.optimizers import Adam
from keras.callbacks import TensorBoard
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.wrappers.scikit_learn import KerasRegressor
import tensorflow as tf
import keras
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
df1=pd.read_csv('ttrain.csv')

# %%
df2=pd.read_csv('ttest.csv')

# %%
df=df1.append(df2)

# %%
df['Title']=df['Name'].str.extract(' ([A-Za-z]+)\.',expand=False)
df['Title'].value_counts()
# Out:
# Mr          757
# Miss        260
# Mrs         197
# Master       61
# Rev           8
# Dr            8
# Col           4
# Mlle          2
# Major         2
# Ms            2
# Lady          1
# Sir           1
# Mme           1
# Don           1
# Capt          1
# Countess      1
# Jonkheer      1
# Dona          1
# Name: Title, dtype: int64

# %%
df['Title']=df['Title'].replace(['Ms','Mlle','Master'],'Miss')
df['Title']=df['Title'].replace(['Mme','Countess','Lady','Dona'],'Mrs')
df['Title']=df['Title'].replace(['Dr','Major','Col','Sir','Rev','Jonkheer','Capt','Don'],'Mr')

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Fare'].fillna(df['Fare'].mean(),inplace=True)

# %%
df['Embarked'].fillna('S')
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 413    S
# 414    C
# 415    S
# 416    S
# 417    C
# Name: Embarked, Length: 1309, dtype: object

# %%
df['Family']=df['SibSp']+df['Parch']+1

# %%
df['Single']=df.Family<2
df['Small']=(df.Family>1)&(df.Family<5)
df['Medium']=(df.Family>4)&(df.Family<7)
df['Large']=df.Family>6

# %%
df.drop(['PassengerId','Ticket','Cabin'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0       3                            Braund, Mr. Owen Harris
# 1         1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1.0       3                             Heikkinen, Miss. Laina
# 3         1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0.0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 413       NaN       3                                 Spector, Mr. Woolf
# 414       NaN       1                       Oliva y Ocana, Dona. Fermina
# 415       NaN       3                       Saether, Mr. Simon Sivertsen
# 416       NaN       3                                Ware, Mr. Frederick
# 417       NaN       3                           Peter, Master. Michael J
#
#         Sex        Age  SibSp  Parch      Fare Embarked Title  Family  Single  \
# 0      male  22.000000      1      0    7.2500        S    Mr       2   False
# 1    female  38.000000      1      0   71.2833        C   Mrs       2   False
# 2    female  26.000000      0      0    7.9250        S  Miss       1    True
# 3    female  35.000000      1      0   53.1000        S   Mrs       2   False
# 4      male  35.000000      0      0    8.0500        S    Mr       1    True
# ..      ...        ...    ...    ...       ...      ...   ...     ...     ...
# 413    male  29.881138      0      0    8.0500        S    Mr       1    True
# 414  female  39.000000      0      0  108.9000        C   Mrs       1    True
# 415    male  38.500000      0      0    7.2500        S    Mr       1    True
# 416    male  29.881138      0      0    8.0500        S    Mr       1    True
# 417    male  29.881138      1      1   22.3583        C  Miss       3   False
#
#      Small  Medium  Large
# 0     True   False  False
# 1     True   False  False
# 2    False   False  False
# 3     True   False  False
# 4    False   False  False
# ..     ...     ...    ...
# 413  False   False  False
# 414  False   False  False
# 415  False   False  False
# 416  False   False  False
# 417   True   False  False
#
# [1309 rows x 15 columns]

# %%
df_train=df[:891]
df_test=df[891:]

# %%
x=df_train[['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked','Title','Family','Single','Small','Medium','Medium']]
y=df_train[['Survived']]

# %%
x=pd.get_dummies(x,drop_first=True)
y=pd.get_dummies(y,drop_first=True)

# %%
# hocam bunları internetten buldum ama biryerde hata alıyorum düzeltemedim kontrol edermisiniz

# %% [markdown]
# # X contains all columns except 'Survived'
# x = df_train.drop(['Survived'], axis=1).values.astype(float)
#
# # It is almost always a good idea to perform some scaling of input values when using neural network models (jb).
#
# scale = StandardScaler()
# x = scale.fit_transform(x)
#
# # Y is just the 'Survived' column
# y = df_train['Survived'].values

# %% [markdown]
# verbose=0

# %% [markdown]
# def create_model(optimizer='adam', init='uniform'):
#     # create model
#     if verbose: print("**Create model with optimizer: %s; init: %s" % (optimizer, init) )
#     model = Sequential()
#     model.add(Dense(16, input_dim=x.shape[1], kernel_initializer=init, activation='relu'))
#     model.add(Dense(8, kernel_initializer=init, activation='relu'))
#     model.add(Dense(4, kernel_initializer=init, activation='relu'))
#     model.add(Dense(1, kernel_initializer=init, activation='sigmoid'))
#     # Compile model
#     model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
#     return model

# %% [markdown]
# run_gridsearch = False
#
# if run_gridsearch:
#
#     start_time = time.time()
#     if verbose: print (time.strftime( "%H:%M:%S " + "GridSearch started ... " ) )
#     optimizers = ['rmsprop', 'adam']
#     inits = ['glorot_uniform', 'normal', 'uniform']
#     epochs = [50, 100, 200, 400]
#     batches = [5, 10, 20]
#
#     model = KerasClassifier(build_fn=create_model, verbose=verbose)
#
#     param_grid = dict(optimizer=optimizers, epochs=epochs, batch_size=batches, init=inits)
#     grid = GridSearchCV(estimator=model, param_grid=param_grid)
#     grid_result = grid.fit(x, y)
#
#     # summarize results
#     print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
#     means = grid_result.cv_results_['mean_test_score']
#     stds = grid_result.cv_results_['std_test_score']
#     params = grid_result.cv_results_['params']
#     if verbose:
#         for mean, stdev, param in zip(means, stds, params):
#             print("%f (%f) with: %r" % (mean, stdev, param))
#         elapsed_time = time.time() - start_time
#         print ("Time elapsed: ",timedelta(seconds=elapsed_time))
#
#     best_epochs = grid_result.best_params_['epochs']
#     best_batch_size = grid_result.best_params_['batch_size']
#     best_init = grid_result.best_params_['init']
#     best_optimizer = grid_result.best_params_['optimizer']
#
# else:
#     # pre-selected paramters
#     best_epochs = 200
#     best_batch_size = 5
#     best_init = 'glorot_uniform'
#     best_optimizer = 'rmsprop'

# %%
x = np.asarray(x).astype('float32')

# %% [markdown]
# # Create a classifier with best parameters
# model_pred = KerasClassifier(build_fn=create_model, optimizer=best_optimizer, init=best_init, epochs=best_epochs, batch_size=best_batch_size, verbose=verbose)
# model_pred.fit(x, y)
#
# # Read test data
# df_test = pd.read_csv(df_test,index_col='PassengerId')
# # Prep and clean data
# df_test = prep_data(df_test)
# # Create X_test
# x_test = df_test.values.astype(float)
# # Scaling
# x_test = scale.transform(x_test)
#
# # Predict 'Survived'
# prediction = model_pred.predict(x_test)

# %% [markdown]
# submission = pd.DataFrame({
#     'PassengerId': df_test.index,
#     'Survived': prediction[:,0],
# })
#
# submission.sort_values('PassengerId', inplace=True)
# submission.to_csv('submission-simple-cleansing.csv', index=False)

# %% [markdown]
# model=Sequential()
# model.add(Dense(8,input_dim=8,kernel_initializer='uniform',activation='relu'))
# model.add(Dense(8,kernel_initializer='uniform',activation='relu'))
# model.add(Dense(1,kernel_initializer='uniform',activation='sigmoid'))
# model.add(tf.keras.layers.Dense(256, input_shape=(x.shape[1],), activation='sigmoid'))

# %%
model=Sequential()
model.add(Dense(12,input_dim=8,input_shape=(x.shape[1],),kernel_initializer='uniform',activation='relu'))
model.add(Dense(8,kernel_initializer='uniform',activation='relu'))
model.add(Dense(1,kernel_initializer='uniform',activation='sigmoid'))

#model = Sequential() 
#model.add(Dense(1000, input_shape=(x.shape[1],), activation='relu', input_dim=3)) 
#model.add(Dense(1000, activation='relu')) 
#model.add(Dense(1)) 
#model.compile(optimizer='adam', loss='mae', metrics=['mae'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, 12)                192
#
#  dense_18 (Dense)            (None, 8)                 104
#
#  dense_19 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 305
# Trainable params: 305
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(x,y,epochs=150,batch_size=10,verbose=1)
# Out:
# Epoch 1/150
# 90/90 [==============================] - 1s 1ms/step - loss: 0.6805 - accuracy: 0.6644
# Epoch 2/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.6270 - accuracy: 0.6958
# Epoch 3/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.5873 - accuracy: 0.7059
# Epoch 4/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.5645 - accuracy: 0.7183
# Epoch 5/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.5537 - accuracy: 0.7172
# Epoch 6/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.5280 - accuracy: 0.7396
# Epoch 7/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.5186 - accuracy: 0.7497
# Epoch 8/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.5065 - accuracy: 0.7520
# Epoch 9/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4914 - accuracy: 0.7587
# Epoch 10/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4820 - accuracy: 0.7755
# Epoch 11/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4734 - accuracy: 0.7789
# Epoch 12/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4706 - accuracy: 0.8002
# Epoch 13/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4616 - accuracy: 0.7901
# Epoch 14/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4692 - accuracy: 0.7946
# Epoch 15/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4594 - accuracy: 0.8036
# Epoch 16/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4489 - accuracy: 0.8070
# Epoch 17/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4504 - accuracy: 0.8058
# Epoch 18/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4521 - accuracy: 0.8047
# Epoch 19/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4492 - accuracy: 0.8103
# Epoch 20/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4504 - accuracy: 0.8081
# Epoch 21/150
# 90/90 [==============================] - 0s 992us/step - loss: 0.4423 - accuracy: 0.8126
# Epoch 22/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4471 - accuracy: 0.8070
# Epoch 23/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4356 - accuracy: 0.8137
# Epoch 24/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4377 - accuracy: 0.8159
# Epoch 25/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4459 - accuracy: 0.8148
# Epoch 26/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4354 - accuracy: 0.8148
# Epoch 27/150
# 90/90 [==============================] - 0s 998us/step - loss: 0.4336 - accuracy: 0.8159
# Epoch 28/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4286 - accuracy: 0.8182
# Epoch 29/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4259 - accuracy: 0.8182
# Epoch 30/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4273 - accuracy: 0.8182
# Epoch 31/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4251 - accuracy: 0.8215
# Epoch 32/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4244 - accuracy: 0.8126
# Epoch 33/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4254 - accuracy: 0.8215
# Epoch 34/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4264 - accuracy: 0.8148
# Epoch 35/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4220 - accuracy: 0.8182
# Epoch 36/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4251 - accuracy: 0.8193
# Epoch 37/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4262 - accuracy: 0.8193
# Epoch 38/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4214 - accuracy: 0.8227
# Epoch 39/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4266 - accuracy: 0.8193
# Epoch 40/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4164 - accuracy: 0.8260
# Epoch 41/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4265 - accuracy: 0.8137
# Epoch 42/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4268 - accuracy: 0.8137
# Epoch 43/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4199 - accuracy: 0.8159
# Epoch 44/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4170 - accuracy: 0.8182
# Epoch 45/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4202 - accuracy: 0.8092
# Epoch 46/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4235 - accuracy: 0.8204
# Epoch 47/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4224 - accuracy: 0.8182
# Epoch 48/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4255 - accuracy: 0.8137
# Epoch 49/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4222 - accuracy: 0.8193
# Epoch 50/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4209 - accuracy: 0.8215
# Epoch 51/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4125 - accuracy: 0.8204
# Epoch 52/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4176 - accuracy: 0.8193
# Epoch 53/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4171 - accuracy: 0.8193
# Epoch 54/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4167 - accuracy: 0.8171
# Epoch 55/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4150 - accuracy: 0.8215
# Epoch 56/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4179 - accuracy: 0.8137
# Epoch 57/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4118 - accuracy: 0.8193
# Epoch 58/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4173 - accuracy: 0.8182
# Epoch 59/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4129 - accuracy: 0.8238
# Epoch 60/150
# 90/90 [==============================] - 0s 985us/step - loss: 0.4120 - accuracy: 0.8215
# Epoch 61/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4157 - accuracy: 0.8227
# Epoch 62/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4107 - accuracy: 0.8148
# Epoch 63/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4128 - accuracy: 0.8215
# Epoch 64/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4150 - accuracy: 0.8238
# Epoch 65/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4157 - accuracy: 0.8182
# Epoch 66/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4122 - accuracy: 0.8272
# Epoch 67/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4109 - accuracy: 0.8204
# Epoch 68/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4078 - accuracy: 0.8193
# Epoch 69/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4129 - accuracy: 0.8272
# Epoch 70/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4099 - accuracy: 0.8316
# Epoch 71/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4095 - accuracy: 0.8238
# Epoch 72/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4072 - accuracy: 0.8260
# Epoch 73/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4104 - accuracy: 0.8204
# Epoch 74/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4080 - accuracy: 0.8249
# Epoch 75/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4118 - accuracy: 0.8159
# Epoch 76/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4124 - accuracy: 0.8227
# Epoch 77/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4062 - accuracy: 0.8294
# Epoch 78/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4105 - accuracy: 0.8182
# Epoch 79/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4074 - accuracy: 0.8227
# Epoch 80/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4089 - accuracy: 0.8238
# Epoch 81/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4109 - accuracy: 0.8260
# Epoch 82/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4054 - accuracy: 0.8193
# Epoch 83/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4123 - accuracy: 0.8260
# Epoch 84/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4044 - accuracy: 0.8283
# Epoch 85/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4107 - accuracy: 0.8193
# Epoch 86/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4265 - accuracy: 0.8193
# Epoch 87/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4043 - accuracy: 0.8249
# Epoch 88/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4048 - accuracy: 0.8294
# Epoch 89/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4039 - accuracy: 0.8294
# Epoch 90/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4060 - accuracy: 0.8283
# Epoch 91/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4028 - accuracy: 0.8249
# Epoch 92/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4041 - accuracy: 0.8294
# Epoch 93/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4046 - accuracy: 0.8272
# Epoch 94/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4022 - accuracy: 0.8283
# Epoch 95/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4056 - accuracy: 0.8182
# Epoch 96/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4038 - accuracy: 0.8272
# Epoch 97/150
# 90/90 [==============================] - 0s 987us/step - loss: 0.4028 - accuracy: 0.8260
# Epoch 98/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4090 - accuracy: 0.8249
# Epoch 99/150
# 90/90 [==============================] - 0s 952us/step - loss: 0.4067 - accuracy: 0.8272
# Epoch 100/150
# 90/90 [==============================] - 0s 985us/step - loss: 0.4057 - accuracy: 0.8204
# Epoch 101/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4019 - accuracy: 0.8227
# Epoch 102/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4089 - accuracy: 0.8238
# Epoch 103/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4035 - accuracy: 0.8238
# Epoch 104/150
# 90/90 [==============================] - 0s 1000us/step - loss: 0.4021 - accuracy: 0.8249
# Epoch 105/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4021 - accuracy: 0.8305
# Epoch 106/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3968 - accuracy: 0.8249
# Epoch 107/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3995 - accuracy: 0.8260
# Epoch 108/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4012 - accuracy: 0.8361
# Epoch 109/150
# 90/90 [==============================] - 0s 987us/step - loss: 0.4008 - accuracy: 0.8350
# Epoch 110/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3995 - accuracy: 0.8316
# Epoch 111/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4068 - accuracy: 0.8260
# Epoch 112/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3974 - accuracy: 0.8328
# Epoch 113/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4007 - accuracy: 0.8249
# Epoch 114/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3984 - accuracy: 0.8283
# Epoch 115/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4028 - accuracy: 0.8260
# Epoch 116/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4024 - accuracy: 0.8260
# Epoch 117/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4081 - accuracy: 0.8193
# Epoch 118/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3965 - accuracy: 0.8328
# Epoch 119/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3986 - accuracy: 0.8339
# Epoch 120/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3966 - accuracy: 0.8339
# Epoch 121/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3964 - accuracy: 0.8350
# Epoch 122/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3985 - accuracy: 0.8260
# Epoch 123/150
# 90/90 [==============================] - 0s 2ms/step - loss: 0.4037 - accuracy: 0.8316
# Epoch 124/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4062 - accuracy: 0.8227
# Epoch 125/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3962 - accuracy: 0.8339
# Epoch 126/150
# 90/90 [==============================] - 0s 2ms/step - loss: 0.3983 - accuracy: 0.8294
# Epoch 127/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3975 - accuracy: 0.8339
# Epoch 128/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3972 - accuracy: 0.8328
# Epoch 129/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3965 - accuracy: 0.8328
# Epoch 130/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3943 - accuracy: 0.8294
# Epoch 131/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3978 - accuracy: 0.8238
# Epoch 132/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3997 - accuracy: 0.8305
# Epoch 133/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4019 - accuracy: 0.8328
# Epoch 134/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4001 - accuracy: 0.8272
# Epoch 135/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3961 - accuracy: 0.8305
# Epoch 136/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3964 - accuracy: 0.8328
# Epoch 137/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3973 - accuracy: 0.8249
# Epoch 138/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3972 - accuracy: 0.8361
# Epoch 139/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3974 - accuracy: 0.8215
# Epoch 140/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3928 - accuracy: 0.8316
# Epoch 141/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3933 - accuracy: 0.8328
# Epoch 142/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3949 - accuracy: 0.8350
# Epoch 143/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3920 - accuracy: 0.8305
# Epoch 144/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3916 - accuracy: 0.8227
# Epoch 145/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3973 - accuracy: 0.8294
# Epoch 146/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3928 - accuracy: 0.8339
# Epoch 147/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.4007 - accuracy: 0.8316
# Epoch 148/150
# 90/90 [==============================] - 0s 995us/step - loss: 0.3933 - accuracy: 0.8361
# Epoch 149/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3946 - accuracy: 0.8283
# Epoch 150/150
# 90/90 [==============================] - 0s 1ms/step - loss: 0.3993 - accuracy: 0.8249

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, 12)                192
#
#  dense_18 (Dense)            (None, 8)                 104
#
#  dense_19 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 305
# Trainable params: 305
# Non-trainable params: 0
# _________________________________________________________________

# %%
scores=model.evaluate(x,y)
# Out:
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3924 - accuracy: 0.8182

# %%
print('%s: %.2f%%'%(model.metrics_names[1], scores[1]*100))
# Out:
# accuracy: 81.82%
