# %%
pip install pycaret
# Out:
# Collecting pycaret
#   Downloading pycaret-2.3.10-py3-none-any.whl (320 kB)
# Requirement already satisfied: ipywidgets in c:\programdata\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Collecting numba<0.55
#   Downloading numba-0.54.1-cp39-cp39-win_amd64.whl (2.3 MB)
# Collecting mlxtend>=0.17.0
#   Downloading mlxtend-0.20.0-py2.py3-none-any.whl (1.3 MB)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from pycaret) (3.5.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from pycaret) (1.1.0)
# Collecting wordcloud
#   Using cached wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Collecting kmodes>=0.10.1
#   Downloading kmodes-0.12.1-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: IPython in c:\programdata\anaconda3\lib\site-packages (from pycaret) (8.2.0)
# Collecting cufflinks>=0.17.0
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
# Requirement already satisfied: seaborn in c:\programdata\anaconda3\lib\site-packages (from pycaret) (0.11.2)
# Collecting imbalanced-learn==0.7.0
#   Downloading imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: plotly>=4.4.1 in c:\programdata\anaconda3\lib\site-packages (from pycaret) (5.6.0)
# Collecting gensim<4.0.0
#   Downloading gensim-3.8.3.tar.gz (23.4 MB)
# Collecting Boruta
#   Downloading Boruta-0.3-py3-none-any.whl (56 kB)
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (from pycaret) (3.7)
# Collecting mlflow
#   Downloading mlflow-1.27.0-py3-none-any.whl (17.9 MB)
# Collecting scipy<=1.5.4
#   Downloading scipy-1.5.4-cp39-cp39-win_amd64.whl (31.4 MB)
# Collecting spacy<2.4.0
#   Downloading spacy-2.3.7-cp39-cp39-win_amd64.whl (9.4 MB)
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting scikit-learn==0.23.2
#   Downloading scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Collecting pycaret
#   Downloading pycaret-2.3.9-py3-none-any.whl (319 kB)
#   Downloading pycaret-2.3.8-py3-none-any.whl (318 kB)
#   Downloading pycaret-2.3.7-py3-none-any.whl (318 kB)
#   Downloading pycaret-2.3.6-py3-none-any.whl (301 kB)
#   Downloading pycaret-2.3.5-py3-none-any.whl (288 kB)
# Collecting numpy==1.19.5
#   Downloading numpy-1.19.5-cp39-cp39-win_amd64.whl (13.3 MB)
# Collecting pycaret
#   Downloading pycaret-2.3.4-py3-none-any.whl (266 kB)
# Collecting numba<0.54
#   Downloading numba-0.53.1-cp39-cp39-win_amd64.whl (2.3 MB)
# Collecting pycaret
#   Downloading pycaret-2.3.3-py3-none-any.whl (264 kB)
#   Downloading pycaret-2.3.2-py3-none-any.whl (263 kB)
#   Downloading pycaret-2.3.1-py3-none-any.whl (261 kB)
#   Downloading pycaret-2.3.0-py3-none-any.whl (261 kB)
# Collecting imbalanced-learn>=0.7.0
#   Downloading imbalanced_learn-0.9.1-py3-none-any.whl (199 kB)
# Requirement already satisfied: gensim in c:\programdata\anaconda3\lib\site-packages (from pycaret) (4.1.2)
# Collecting pycaret
#   Downloading pycaret-2.2.3-py3-none-any.whl (249 kB)
# Collecting spacy
#   Downloading spacy-3.4.0-cp39-cp39-win_amd64.whl (11.8 MB)
# Collecting catboost>=0.23.2
#   Downloading catboost-1.0.6-cp39-none-win_amd64.whl (73.9 MB)
# Collecting xgboost>=1.1.0
#   Downloading xgboost-1.6.1-py3-none-win_amd64.whl (125.4 MB)
# Collecting pycaret
#   Downloading pycaret-2.2.2-py3-none-any.whl (249 kB)
# Requirement already satisfied: scikit-learn>=0.23.2 in c:\programdata\anaconda3\lib\site-packages (from pycaret) (1.0.2)
# Collecting pandas-profiling>=2.8.0
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Collecting pyod
#   Downloading pyod-1.0.3.tar.gz (125 kB)
# Collecting yellowbrick>=1.0.1
#   Downloading yellowbrick-1.4-py3-none-any.whl (274 kB)
# Collecting lightgbm>=2.3.1
#   Downloading lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from pycaret) (1.21.5)
# Collecting textblob
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret) (1.7.3)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret) (1.16.0)
# Collecting graphviz
#   Downloading graphviz-0.20-py3-none-any.whl (46 kB)
# Collecting colorlover>=0.2.1
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools>=34.4.1 in c:\programdata\anaconda3\lib\site-packages (from cufflinks>=0.17.0->pycaret) (61.2.0)
# Collecting scikit-learn>=0.23.2
#   Downloading scikit_learn-1.1.1-cp39-cp39-win_amd64.whl (7.4 MB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn>=0.7.0->pycaret) (2.2.0)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (0.1.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (0.3.9)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (0.18.1)
# Requirement already satisfied: traitlets>=5 in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (2.11.2)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (3.0.20)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->pycaret) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->pycaret) (6.9.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->pycaret) (5.3.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->pycaret) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->pycaret) (0.2.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1.12)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.5.5)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->IPython->pycaret) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\programdata\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in c:\programdata\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (302)
# Requirement already satisfied: wheel in c:\programdata\anaconda3\lib\site-packages (from lightgbm>=2.3.1->pycaret) (0.37.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (2.15.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret) (21.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->pycaret) (2021.3)
# Collecting missingno>=0.4.2
#   Using cached missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Collecting phik>=0.11.1
#   Using cached phik-0.12.2-cp39-cp39-win_amd64.whl (685 kB)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (6.0)
# Collecting markupsafe~=2.1.1
#   Using cached MarkupSafe-2.1.1-cp39-cp39-win_amd64.whl (17 kB)
# Requirement already satisfied: jinja2>=2.11.1 in c:\programdata\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (2.11.3)
# Collecting multimethod>=1.4
#   Using cached multimethod-1.8-py3-none-any.whl (9.8 kB)
# Collecting pydantic>=1.8.1
#   Using cached pydantic-1.9.1-cp39-cp39-win_amd64.whl (2.0 MB)
# Collecting visions[type_image_path]==0.7.4
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Requirement already satisfied: requests>=2.24.0 in c:\programdata\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (2.27.1)
# Collecting tangled-up-in-unicode==0.2.0
#   Using cached tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Collecting htmlmin>=0.1.12
#   Using cached htmlmin-0.1.12-py3-none-any.whl
# Requirement already satisfied: tqdm>=4.48.2 in c:\programdata\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (4.64.0)
# Requirement already satisfied: networkx>=2.4 in c:\programdata\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (2.7.1)
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (9.0.1)
# Collecting imagehash
#   Using cached ImageHash-4.2.1-py2.py3-none-any.whl
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pycaret) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pycaret) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pycaret) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pycaret) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pycaret) (3.0.4)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from plotly>=4.4.1->pycaret) (8.0.1)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling>=2.8.0->pycaret) (4.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (3.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\programdata\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.4.8)
# Requirement already satisfied: argon2-cffi in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.8.0)
# Requirement already satisfied: nbconvert in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.4.4)
# Requirement already satisfied: prometheus-client in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.13.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.15.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.21)
# Requirement already satisfied: smart-open>=1.8.1 in c:\programdata\anaconda3\lib\site-packages (from gensim->pycaret) (5.1.0)
# Requirement already satisfied: PyWavelets in c:\programdata\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (1.3.0)
# Collecting alembic
#   Downloading alembic-1.8.1-py3-none-any.whl (209 kB)
# Collecting gitpython>=2.1.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.17.0.tar.gz (81 kB)
# Collecting sqlparse>=0.3.1
#   Downloading sqlparse-0.4.2-py3-none-any.whl (42 kB)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from mlflow->pycaret) (2.0.0)
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting docker>=4.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Requirement already satisfied: Flask in c:\programdata\anaconda3\lib\site-packages (from mlflow->pycaret) (1.1.2)
# Requirement already satisfied: sqlalchemy>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow->pycaret) (1.4.32)
# Requirement already satisfied: protobuf>=3.12.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow->pycaret) (3.19.1)
# Collecting prometheus-flask-exporter
#   Downloading prometheus_flask_exporter-0.20.2-py3-none-any.whl (18 kB)
# Requirement already satisfied: click>=7.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow->pycaret) (8.0.4)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow->pycaret) (4.11.3)
# Requirement already satisfied: entrypoints in c:\programdata\anaconda3\lib\site-packages (from mlflow->pycaret) (0.4)
# Collecting waitress
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from databricks-cli>=0.8.7->mlflow->pycaret) (2.1.0)
# Collecting oauthlib>=3.1.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: tabulate>=0.7.7 in c:\programdata\anaconda3\lib\site-packages (from databricks-cli>=0.8.7->mlflow->pycaret) (0.8.9)
# Collecting pywin32>=1.0
#   Downloading pywin32-227-cp39-cp39-win_amd64.whl (9.1 MB)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\programdata\anaconda3\lib\site-packages (from docker>=4.0.0->mlflow->pycaret) (0.58.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->pycaret) (3.7.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy>=1.4.0->mlflow->pycaret) (1.1.1)
# Collecting Mako
#   Downloading Mako-1.2.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: itsdangerous>=0.24 in c:\programdata\anaconda3\lib\site-packages (from Flask->mlflow->pycaret) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\programdata\anaconda3\lib\site-packages (from Flask->mlflow->pycaret) (2.0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.5.0)
# Requirement already satisfied: testpath in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.8.4)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.7.1)
# Requirement already satisfied: bleach in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.13)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk->pycaret) (2022.3.15)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied: numexpr in c:\programdata\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (2.8.1)
# Collecting funcy
#   Downloading funcy-1.17-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: future in c:\programdata\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (0.18.2)
# Requirement already satisfied: numba>=0.51 in c:\programdata\anaconda3\lib\site-packages (from pyod->pycaret) (0.55.1)
# Requirement already satisfied: statsmodels in c:\programdata\anaconda3\lib\site-packages (from pyod->pycaret) (0.13.2)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\programdata\anaconda3\lib\site-packages (from numba>=0.51->pyod->pycaret) (0.38.0)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.2-py3-none-any.whl (7.2 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.7-cp39-cp39-win_amd64.whl (18 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Downloading spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Collecting thinc<8.2.0,>=8.1.0
#   Downloading thinc-8.1.0-cp39-cp39-win_amd64.whl (1.3 MB)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.2-py3-none-any.whl (27 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.6-cp39-cp39-win_amd64.whl (36 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.2-py3-none-any.whl (42 kB)
# Collecting wasabi<1.1.0,>=0.9.1
#   Downloading wasabi-0.9.1-py3-none-any.whl (26 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.6-cp39-cp39-win_amd64.whl (112 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.7-py3-none-any.whl (17 kB)
# Collecting srsly<3.0.0,>=2.4.3
# Note: you may need to restart the kernel to use updated packages.  Downloading srsly-2.4.3-cp39-cp39-win_amd64.whl (448 kB)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
# Collecting blis<0.8.0,>=0.7.8
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\ProgramData\Anaconda3\python.exe' 'C:\Users\behlul\AppData\Local\Temp\pip-standalone-pip-dc4duqnf\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\behlul\AppData\Local\Temp\pip-build-env-tgvgniuf\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1'
#        cwd: None
#   Complete output (595 lines):
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation != "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-63.2.0-py3-none-any.whl (1.2 MB)
#   Collecting wheel
#     Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
#   Collecting Cython>=0.28.5
#     Downloading Cython-0.29.30-py2.py3-none-any.whl (985 kB)
#   Collecting numpy==1.17.3
#     Downloading numpy-1.17.3.zip (6.4 MB)
#   Collecting scipy>=0.19.1
#     Downloading scipy-1.8.1-cp39-cp39-win_amd64.whl (36.9 MB)
#   Building wheels for collected packages: numpy
#     Building wheel for numpy (setup.py): started
#     Building wheel for numpy (setup.py): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\ProgramData\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-i9kain0d\\numpy_d8e3cf8a42a444818658ecb3425ba09e\\setup.py'"'"'; __file__='"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-i9kain0d\\numpy_d8e3cf8a42a444818658ecb3425ba09e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\behlul\AppData\Local\Temp\pip-wheel-99254d_q'
#          cwd: C:\Users\behlul\AppData\Local\Temp\pip-install-i9kain0d\numpy_d8e3cf8a42a444818658ecb3425ba09e\
#     Complete output (268 lines):
#     Running from numpy source directory.
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blis not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\behlul\AppData\Local\Temp\pip-install-i9kain0d\numpy_d8e3cf8a42a444818658ecb3425ba09e\numpy\distutils\system_info.py:690: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       self.calc_info()
#     blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\behlul\AppData\Local\Temp\pip-install-i9kain0d\numpy_d8e3cf8a42a444818658ecb3425ba09e\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\behlul\AppData\Local\Temp\pip-install-i9kain0d\numpy_d8e3cf8a42a444818658ecb3425ba09e\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     'svnversion' is not recognized as an internal or external command,
#     operable program or batch file.
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas,lapack not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     flame_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries flame not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in c:\ProgramData\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in c:\ProgramData\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in c:\ProgramData\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in c:\ProgramData\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#   Downloading blis-0.7.8-cp39-cp39-win_amd64.whl (6.6 MB)
# Requirement already satisfied: executing in c:\programdata\anaconda3\lib\site-packages (from stack-data->IPython->pycaret) (0.8.3)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\lib\site-packages (from stack-data->IPython->pycaret) (0.2.2)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\lib\site-packages (from stack-data->IPython->pycaret) (2.0.5)
# Requirement already satisfied: patsy>=0.5.2 in c:\programdata\anaconda3\lib\site-packages (from statsmodels->pyod->pycaret) (0.5.2)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.7.tar.gz (1.1 MB)
# Building wheels for collected packages: cufflinks, databricks-cli, pyLDAvis, pyod, sklearn, umap-learn, pynndescent
#   Building wheel for cufflinks (setup.py): started
#   Building wheel for cufflinks (setup.py): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68736 sha256=2d683e0fdacc00b94db30cdfe853161689a31664df340232082629f67df18173
#   Stored in directory: c:\users\behlul\appdata\local\pip\cache\wheels\29\b4\f8\2fd2206eeeba6ccad8167e4e8894b8c4ec27bf1342037fd136
#   Building wheel for databricks-cli (setup.py): started
#   Building wheel for databricks-cli (setup.py): finished with status 'done'
#   Created wheel for databricks-cli: filename=databricks_cli-0.17.0-py3-none-any.whl size=141954 sha256=14ebf582524e173cd59a8cb912473c2820976f8366d973b9ab9695b607a2d8ed
#   Stored in directory: c:\users\behlul\appdata\local\pip\cache\wheels\d5\b6\71\c3052c82e4a88dc658dd2616b944e130c1d0ff3f77e8f02df7
#   Building wheel for pyLDAvis (PEP 517): started
#   Building wheel for pyLDAvis (PEP 517): finished with status 'done'
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136882 sha256=902c3420b7a7a137fadd45fa3cff9247d6a632fe629106a0404e51029c9cf568
#   Stored in directory: c:\users\behlul\appdata\local\pip\cache\wheels\57\a4\86\d10c6c2e0bf149fbc0afb0aa5a6528ac35b30a133a0270c477
#   Building wheel for pyod (setup.py): started
#   Building wheel for pyod (setup.py): finished with status 'done'
#   Created wheel for pyod: filename=pyod-1.0.3-py3-none-any.whl size=154727 sha256=af0a5ffd042d8aa5c526cf38a117302549bd45117443828c61c857456aabbfe4
#   Stored in directory: c:\users\behlul\appdata\local\pip\cache\wheels\e7\7f\42\b327c84bc27e4bdc543dd0443189536cbf4ec7faf849f5d71a
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=a18848f452a47264ea60c29fdac878103a3ea572bf6be3d42b03153d8c95263f
#   Stored in directory: c:\users\behlul\appdata\local\pip\cache\wheels\e4\7b\98\b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
#   Building wheel for umap-learn (setup.py): started
#   Building wheel for umap-learn (setup.py): finished with status 'done'
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=489fba305dddd8725cce9bdf0509d6a46a5f46a2d3ebc25dd57087fe1e35cdd2
#   Stored in directory: c:\users\behlul\appdata\local\pip\cache\wheels\f4\3e\1c\596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for pynndescent (setup.py): started
#   Building wheel for pynndescent (setup.py): finished with status 'done'
#   Created wheel for pynndescent: filename=pynndescent-0.5.7-py3-none-any.whl size=54286 sha256=a5437e37e6ebd981489f0b6df3a8596c5757815fdd8d97018181fc287ae0d66d
#   Stored in directory: c:\users\behlul\appdata\local\pip\cache\wheels\5b\f5\6e\aac11d69fe2115d9ac871d6c148b361f0d3f8a35ed7354fa03
# Successfully built cufflinks databricks-cli pyLDAvis pyod sklearn umap-learn pynndescent
# Installing collected packages: pywin32, markupsafe, tangled-up-in-unicode, smmap, murmurhash, multimethod, cymem, catalogue, wasabi, visions, typer, srsly, smart-open, scikit-learn, pydantic, preshed, oauthlib, Mako, imagehash, gitdb, blis, waitress, thinc, sqlparse, spacy-loggers, spacy-legacy, sklearn, querystring-parser, pynndescent, prometheus-flask-exporter, phik, pathy, missingno, langcodes, htmlmin, graphviz, gitpython, funcy, docker, databricks-cli, colorlover, alembic, yellowbrick, xgboost, wordcloud, umap-learn, textblob, spacy, scikit-plot, pyod, pyLDAvis, pandas-profiling, mlxtend, mlflow, lightgbm, kmodes, imbalanced-learn, cufflinks, catboost, pycaret
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 302
#     Uninstalling pywin32-302:
#     lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\behlul\AppData\Local\Temp\pip-install-i9kain0d\numpy_d8e3cf8a42a444818658ecb3425ba09e\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\behlul\AppData\Local\Temp\pip-install-i9kain0d\numpy_d8e3cf8a42a444818658ecb3425ba09e\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#       NOT AVAILABLE
#
#     c:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running bdist_wheel
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     creating build
#     creating build\src.win-amd64-3.9
#     creating build\src.win-amd64-3.9\numpy
#     creating build\src.win-amd64-3.9\numpy\distutils
#     building library "npymath" sources
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
#     ERROR: Failed building wheel for numpy
#     Running setup.py clean for numpy
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\ProgramData\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-i9kain0d\\numpy_d8e3cf8a42a444818658ecb3425ba09e\\setup.py'"'"'; __file__='"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-i9kain0d\\numpy_d8e3cf8a42a444818658ecb3425ba09e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#          cwd: C:\Users\behlul\AppData\Local\Temp\pip-install-i9kain0d\numpy_d8e3cf8a42a444818658ecb3425ba09e
#     Complete output (10 lines):
#     Running from numpy source directory.
#
#     `setup.py clean` is not supported, use one of the following instead:
#
#       - `git clean -xdf` (cleans all files)
#       - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                           files that aren't checked into the git repo)
#
#     Add `--force` to your command to use it anyway if you must (unsupported).
#
#     ----------------------------------------
#     ERROR: Failed cleaning build dir for numpy
#   Failed to build numpy
#   Installing collected packages: numpy, wheel, setuptools, scipy, Cython
#       Running setup.py install for numpy: started
#       Running setup.py install for numpy: finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'c:\ProgramData\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-i9kain0d\\numpy_d8e3cf8a42a444818658ecb3425ba09e\\setup.py'"'"'; __file__='"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-i9kain0d\\numpy_d8e3cf8a42a444818658ecb3425ba09e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\behlul\AppData\Local\Temp\pip-record-7t_avb37\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\behlul\AppData\Local\Temp\pip-build-env-tgvgniuf\overlay' --compile --install-headers 'C:\Users\behlul\AppData\Local\Temp\pip-build-env-tgvgniuf\overlay\Include\numpy'
#            cwd: C:\Users\behlul\AppData\Local\Temp\pip-install-i9kain0d\numpy_d8e3cf8a42a444818658ecb3425ba09e\
#       Complete output (275 lines):
#       Running from numpy source directory.
#
#       Note: if you need reliable uninstall behavior, then install
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install numpy`   (last NumPy release on PyPi)
#
#
#       blas_opt_info:
#       blas_mkl_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries mkl_rt not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       blis_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries blis not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#       customize GnuFCompiler
#       Could not locate executable g77
#       Could not locate executable f77
#       customize IntelVisualFCompiler
#       Could not locate executable ifort
#       Could not locate executable ifl
#       customize AbsoftFCompiler
#       Could not locate executable f90
#       customize CompaqVisualFCompiler
#       Could not locate executable DF
#       customize IntelItaniumVisualFCompiler
#       Could not locate executable efl
#       customize Gnu95FCompiler
#       Could not locate executable gfortran
#       Could not locate executable f95
#       customize G95FCompiler
#       Could not locate executable g95
#       customize IntelEM64VisualFCompiler
#       customize IntelEM64TFCompiler
#       Could not locate executable efort
#       Could not locate executable efc
#       customize PGroupFlangCompiler
#       Could not locate executable flang
#       don't know how to compile Fortran code on platform 'nt'
#         NOT AVAILABLE
#
#       atlas_3_10_blas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       accelerate_info:
#         NOT AVAILABLE
#
#       C:\Users\behlul\AppData\Local\Temp\pip-install-i9kain0d\numpy_d8e3cf8a42a444818658ecb3425ba09e\numpy\distutils\system_info.py:690: UserWarning:
#           Optimized (vendor) Blas libraries are not found.
#           Falls back to netlib Blas library which has worse performance.
#           A better performance should be easily gained by switching
#           Blas library.
#         self.calc_info()
#       blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries blas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\behlul\AppData\Local\Temp\pip-install-i9kain0d\numpy_d8e3cf8a42a444818658ecb3425ba09e\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         self.calc_info()
#       blas_src_info:
#         NOT AVAILABLE
#
#       C:\Users\behlul\AppData\Local\Temp\pip-install-i9kain0d\numpy_d8e3cf8a42a444818658ecb3425ba09e\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         self.calc_info()
#         NOT AVAILABLE
#
#       'svnversion' is not recognized as an internal or external command,
#       operable program or batch file.
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       lapack_opt_info:
#       lapack_mkl_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries mkl_rt not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_lapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_clapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas,lapack not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       flame_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries flame not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in c:\ProgramData\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#         NOT AVAILABLE
#
#       atlas_3_10_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in c:\ProgramData\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_info'>
#         NOT AVAILABLE
#
#       atlas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in c:\ProgramData\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_threads_info'>
#         NOT AVAILABLE
#
#       atlas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in c:\ProgramData\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_info'>
#         NOT AVAILABLE
#
#       lapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\behlul\AppData\Local\Temp\pip-install-i9kain0d\numpy_d8e3cf8a42a444818658ecb3425ba09e\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#       lapack_src_info:
#         NOT AVAILABLE
#
#       C:\Users\behlul\AppData\Local\Temp\pip-install-i9kain0d\numpy_d8e3cf8a42a444818658ecb3425ba09e\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#         NOT AVAILABLE
#
#       c:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running install
#       c:\ProgramData\Anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running config_cc
#       unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       build_src
#       building py_modules sources
#       building library "npymath" sources
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#   ERROR: Command errored out with exit status 1: 'c:\ProgramData\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-i9kain0d\\numpy_d8e3cf8a42a444818658ecb3425ba09e\\setup.py'"'"'; __file__='"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-i9kain0d\\numpy_d8e3cf8a42a444818658ecb3425ba09e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\behlul\AppData\Local\Temp\pip-record-7t_avb37\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\behlul\AppData\Local\Temp\pip-build-env-tgvgniuf\overlay' --compile --install-headers 'C:\Users\behlul\AppData\Local\Temp\pip-build-env-tgvgniuf\overlay\Include\numpy' Check the logs for full command output.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/aa/f6/75297be19f48b7a8c2577753a3a700f98fc4db49d0e5ed3820dd8dee43d4/scikit-learn-0.23.2.tar.gz#sha256=20766f515e6cd6f954554387dfae705d93c7b544ec0e6c6a5d8e006f6f7ef480 (from https://pypi.org/simple/scikit-learn/) (requires-python:>=3.6). Command errored out with exit status 1: 'c:\ProgramData\Anaconda3\python.exe' 'C:\Users\behlul\AppData\Local\Temp\pip-standalone-pip-dc4duqnf\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\behlul\AppData\Local\Temp\pip-build-env-tgvgniuf\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1' Check the logs for full command output.
# ERROR: Could not install packages due to an OSError: [WinError 5] Erişim engellendi: 'c:\\programdata\\anaconda3\\lib\\site-packages\\__pycache__\\pythoncom.cpython-39.pyc'
# Consider using the `--user` option or check the permissions.

# %%
pip install --user pycaret
# Out:
# Collecting pycaret
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (from pycaret) (3.7)
# Collecting pandas-profiling>=2.8.0
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Collecting imbalanced-learn==0.7.0
#   Using cached imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
# Collecting Boruta
#   Using cached Boruta-0.3-py3-none-any.whl (56 kB)
# Collecting gensim<4.0.0
#   Using cached gensim-3.8.3.tar.gz (23.4 MB)
# Collecting numba<0.55
#   Using cached numba-0.54.1-cp39-cp39-win_amd64.whl (2.3 MB)
# Collecting pyLDAvis
#   Using cached pyLDAvis-3.3.1-py2.py3-none-any.whl
# Collecting pyyaml<6.0.0
#   Downloading PyYAML-5.4.1-cp39-cp39-win_amd64.whl (213 kB)
# Collecting mlflow
#   Using cached mlflow-1.27.0-py3-none-any.whl (17.9 MB)
# Requirement already satisfied: IPython in c:\programdata\anaconda3\lib\site-packages (from pycaret) (8.2.0)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from pycaret) (1.4.2)
# Collecting wordcloud
#   Using cached wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Collecting mlxtend>=0.17.0
#   Using cached mlxtend-0.20.0-py2.py3-none-any.whl (1.3 MB)
# Collecting yellowbrick>=1.0.1
#   Using cached yellowbrick-1.4-py3-none-any.whl (274 kB)
# Collecting lightgbm>=2.3.1
#   Using cached lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
# Collecting scikit-learn==0.23.2
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Collecting pycaret
#   Using cached pycaret-2.3.9-py3-none-any.whl (319 kB)
#   Using cached pycaret-2.3.8-py3-none-any.whl (318 kB)
#   Using cached pycaret-2.3.7-py3-none-any.whl (318 kB)
#   Using cached pycaret-2.3.6-py3-none-any.whl (301 kB)
#   Using cached pycaret-2.3.5-py3-none-any.whl (288 kB)
# Collecting numpy==1.19.5
#   Using cached numpy-1.19.5-cp39-cp39-win_amd64.whl (13.3 MB)
# Collecting pycaret
#   Using cached pycaret-2.3.4-py3-none-any.whl (266 kB)
#   Using cached pycaret-2.3.3-py3-none-any.whl (264 kB)
#   Using cached pycaret-2.3.2-py3-none-any.whl (263 kB)
#   Using cached pycaret-2.3.1-py3-none-any.whl (261 kB)
#   Using cached pycaret-2.3.0-py3-none-any.whl (261 kB)Note: you may need to restart the kernel to use updated packages.
#
#   Using cached pycaret-2.2.3-py3-none-any.whl (249 kB)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from pycaret) (1.21.5)
# Collecting spacy
#   Using cached spacy-3.4.0-cp39-cp39-win_amd64.whl (11.8 MB)
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\ProgramData\Anaconda3\python.exe' 'C:\Users\behlul\AppData\Local\Temp\pip-standalone-pip-6ju1qln6\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\behlul\AppData\Local\Temp\pip-build-env-3hvie57p\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1'
#        cwd: None
#   Complete output (595 lines):
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation != "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-63.2.0-py3-none-any.whl (1.2 MB)
#   Collecting wheel
#     Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
#   Collecting Cython>=0.28.5
#     Using cached Cython-0.29.30-py2.py3-none-any.whl (985 kB)
#   Collecting numpy==1.17.3
#     Using cached numpy-1.17.3.zip (6.4 MB)
#   Collecting scipy>=0.19.1
#     Using cached scipy-1.8.1-cp39-cp39-win_amd64.whl (36.9 MB)
#   Building wheels for collected packages: numpy
#     Building wheel for numpy (setup.py): started
#     Building wheel for numpy (setup.py): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\ProgramData\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-ip7k67it\\numpy_3c1761cf807d41e68fb35567d6951357\\setup.py'"'"'; __file__='"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-ip7k67it\\numpy_3c1761cf807d41e68fb35567d6951357\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\behlul\AppData\Local\Temp\pip-wheel-x250fatw'
#          cwd: C:\Users\behlul\AppData\Local\Temp\pip-install-ip7k67it\numpy_3c1761cf807d41e68fb35567d6951357\
#     Complete output (268 lines):
#     Running from numpy source directory.
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blis not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\behlul\AppData\Local\Temp\pip-install-ip7k67it\numpy_3c1761cf807d41e68fb35567d6951357\numpy\distutils\system_info.py:690: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       self.calc_info()
# Collecting xgboost>=1.1.0
#   Using cached xgboost-1.6.1-py3-none-win_amd64.whl (125.4 MB)
# Collecting pycaret
#   Using cached pycaret-2.2.2-py3-none-any.whl (249 kB)
# Collecting imbalanced-learn>=0.7.0
#   Using cached imbalanced_learn-0.9.1-py3-none-any.whl (199 kB)
# Requirement already satisfied: ipywidgets in c:\programdata\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Collecting textblob
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Collecting catboost>=0.23.2
#   Using cached catboost-1.0.6-cp39-none-win_amd64.whl (73.9 MB)
# Collecting cufflinks>=0.17.0
#   Using cached cufflinks-0.17.3-py3-none-any.whl
# Collecting umap-learn
#   Using cached umap_learn-0.5.3-py3-none-any.whl
# Collecting kmodes>=0.10.1
#   Using cached kmodes-0.12.1-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from pycaret) (3.5.1)
# Collecting pyod
#   Using cached pyod-1.0.3-py3-none-any.whl
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from pycaret) (1.1.0)
# Requirement already satisfied: gensim in c:\programdata\anaconda3\lib\site-packages (from pycaret) (4.1.2)
# Collecting scikit-plot
#   Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: scikit-learn>=0.23.2 in c:\programdata\anaconda3\lib\site-packages (from pycaret) (1.0.2)
# Requirement already satisfied: seaborn in c:\programdata\anaconda3\lib\site-packages (from pycaret) (0.11.2)
# Requirement already satisfied: plotly>=4.4.1 in c:\programdata\anaconda3\lib\site-packages (from pycaret) (5.6.0)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret) (1.7.3)
# Collecting graphviz
#   Using cached graphviz-0.20-py3-none-any.whl (46 kB)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret) (1.16.0)
# Collecting colorlover>=0.2.1
#   Using cached colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools>=34.4.1 in c:\programdata\anaconda3\lib\site-packages (from cufflinks>=0.17.0->pycaret) (61.2.0)
# Collecting scikit-learn>=0.23.2
#   Using cached scikit_learn-1.1.1-cp39-cp39-win_amd64.whl (7.4 MB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn>=0.7.0->pycaret) (2.2.0)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (3.0.20)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (0.1.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (2.11.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (0.3.9)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (0.18.1)
# Requirement already satisfied: traitlets>=5 in c:\programdata\anaconda3\lib\site-packages (from IPython->pycaret) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->pycaret) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->pycaret) (5.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->pycaret) (6.9.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->pycaret) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipywidgets->pycaret) (1.0.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->IPython->pycaret) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in c:\programdata\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\programdata\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (4.9.2)
# Requirement already satisfied: pywin32>=1.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (302)
# Requirement already satisfied: wheel in c:\programdata\anaconda3\lib\site-packages (from lightgbm>=2.3.1->pycaret) (0.37.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (2.15.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret) (21.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->pycaret) (2021.3)
# Collecting htmlmin>=0.1.12
#   Using cached htmlmin-0.1.12-py3-none-any.whl
# Requirement already satisfied: requests>=2.24.0 in c:\programdata\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (2.27.1)
# Collecting pydantic>=1.8.1
#   Using cached pydantic-1.9.1-cp39-cp39-win_amd64.whl (2.0 MB)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (6.0)
# Collecting missingno>=0.4.2
#   Using cached missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Collecting markupsafe~=2.1.1
#   Using cached MarkupSafe-2.1.1-cp39-cp39-win_amd64.whl (17 kB)
# Requirement already satisfied: tqdm>=4.48.2 in c:\programdata\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (4.64.0)
# Collecting multimethod>=1.4
#   Using cached multimethod-1.8-py3-none-any.whl (9.8 kB)
# Collecting visions[type_image_path]==0.7.4
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Collecting tangled-up-in-unicode==0.2.0
#   Using cached tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Requirement already satisfied: jinja2>=2.11.1 in c:\programdata\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (2.11.3)
# Collecting phik>=0.11.1
#   Using cached phik-0.12.2-cp39-cp39-win_amd64.whl (685 kB)
# Requirement already satisfied: networkx>=2.4 in c:\programdata\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (2.7.1)
# Collecting imagehash
#   Using cached ImageHash-4.2.1-py2.py3-none-any.whl
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pycaret) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pycaret) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pycaret) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pycaret) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pycaret) (4.25.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from plotly>=4.4.1->pycaret) (8.0.1)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling>=2.8.0->pycaret) (4.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (3.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\programdata\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.4.8)
# Requirement already satisfied: terminado>=0.8.3 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.13.1)
# Requirement already satisfied: nbconvert in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.4.4)
# Requirement already satisfied: prometheus-client in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\programdata\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.15.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.21)
# Requirement already satisfied: smart-open>=1.8.1 in c:\programdata\anaconda3\lib\site-packages (from gensim->pycaret) (5.1.0)
# Requirement already satisfied: PyWavelets in c:\programdata\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (1.3.0)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from mlflow->pycaret) (2.0.0)
# Requirement already satisfied: protobuf>=3.12.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow->pycaret) (3.19.1)
# Collecting sqlparse>=0.3.1
#   Using cached sqlparse-0.4.2-py3-none-any.whl (42 kB)
# Collecting docker>=4.0.0
#   Using cached docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting waitress
#   Using cached waitress-2.1.2-py3-none-any.whl (57 kB)
# Requirement already satisfied: entrypoints in c:\programdata\anaconda3\lib\site-packages (from mlflow->pycaret) (0.4)
# Requirement already satisfied: Flask in c:\programdata\anaconda3\lib\site-packages (from mlflow->pycaret) (1.1.2)
# Collecting querystring-parser
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: click>=7.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow->pycaret) (8.0.4)
# Collecting prometheus-flask-exporter
#   Using cached prometheus_flask_exporter-0.20.2-py3-none-any.whl (18 kB)
# Collecting alembic
#   Using cached alembic-1.8.1-py3-none-any.whl (209 kB)
# Requirement already satisfied: sqlalchemy>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow->pycaret) (1.4.32)
# Collecting gitpython>=2.1.0
#   Using cached GitPython-3.1.27-py3-none-any.whl (181 kB)
# Collecting databricks-cli>=0.8.7
#   Using cached databricks_cli-0.17.0-py3-none-any.whl
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow->pycaret) (4.11.3)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from databricks-cli>=0.8.7->mlflow->pycaret) (2.1.0)
# Collecting oauthlib>=3.1.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: tabulate>=0.7.7 in c:\programdata\anaconda3\lib\site-packages (from databricks-cli>=0.8.7->mlflow->pycaret) (0.8.9)
# Collecting pywin32>=1.0
#   Using cached pywin32-227-cp39-cp39-win_amd64.whl (9.1 MB)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\programdata\anaconda3\lib\site-packages (from docker>=4.0.0->mlflow->pycaret) (0.58.0)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->pycaret) (3.7.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy>=1.4.0->mlflow->pycaret) (1.1.1)
# Collecting Mako
#   Using cached Mako-1.2.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: itsdangerous>=0.24 in c:\programdata\anaconda3\lib\site-packages (from Flask->mlflow->pycaret) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\programdata\anaconda3\lib\site-packages (from Flask->mlflow->pycaret) (2.0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.5.0)
# Requirement already satisfied: bleach in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.8.4)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.1.2)
# Requirement already satisfied: testpath in c:\programdata\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.0)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk->pycaret) (2022.3.15)
# Requirement already satisfied: future in c:\programdata\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (0.18.2)
# Collecting funcy
#   Using cached funcy-1.17-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: numexpr in c:\programdata\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (2.8.1)
# Collecting sklearn
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# Requirement already satisfied: statsmodels in c:\programdata\anaconda3\lib\site-packages (from pyod->pycaret) (0.13.2)
# Requirement already satisfied: numba>=0.51 in c:\programdata\anaconda3\lib\site-packages (from pyod->pycaret) (0.55.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\programdata\anaconda3\lib\site-packages (from numba>=0.51->pyod->pycaret) (0.38.0)
# Collecting wasabi<1.1.0,>=0.9.1
#   Using cached wasabi-0.9.1-py3-none-any.whl (26 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting pathy>=0.3.5
#   Using cached pathy-0.6.2-py3-none-any.whl (42 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.7-cp39-cp39-win_amd64.whl (18 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Using cached srsly-2.4.3-cp39-cp39-win_amd64.whl (448 kB)
# Collecting typer<0.5.0,>=0.3.0
#   Using cached typer-0.4.2-py3-none-any.whl (27 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.6-cp39-cp39-win_amd64.whl (112 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Using cached spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Collecting thinc<8.2.0,>=8.1.0
#   Using cached thinc-8.1.0-cp39-cp39-win_amd64.whl (1.3 MB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.3-py3-none-any.whl (9.3 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.6-cp39-cp39-win_amd64.whl (36 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.7-py3-none-any.whl (17 kB)
# Collecting smart-open>=1.8.1
#   Using cached smart_open-5.2.1-py3-none-any.whl (58 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Using cached blis-0.7.8-cp39-cp39-win_amd64.whl (6.6 MB)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\lib\site-packages (from stack-data->IPython->pycaret) (0.2.2)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\lib\site-packages (from stack-data->IPython->pycaret) (2.0.5)
# Requirement already satisfied: executing in c:\programdata\anaconda3\lib\site-packages (from stack-data->IPython->pycaret) (0.8.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\programdata\anaconda3\lib\site-packages (from statsmodels->pyod->pycaret) (0.5.2)
# Collecting pynndescent>=0.5
#   Using cached pynndescent-0.5.7-py3-none-any.whl
# Installing collected packages: pywin32, markupsafe, tangled-up-in-unicode, smmap, murmurhash, multimethod, cymem, catalogue, wasabi, visions, typer, srsly, smart-open, scikit-learn, pydantic, preshed, oauthlib, Mako, imagehash, gitdb, blis, waitress, thinc, sqlparse, spacy-loggers, spacy-legacy, sklearn, querystring-parser, pynndescent, prometheus-flask-exporter, phik, pathy, missingno, langcodes, htmlmin, graphviz, gitpython, funcy, docker, databricks-cli, colorlover, alembic, yellowbrick, xgboost, wordcloud, umap-learn, textblob, spacy, scikit-plot, pyod, pyLDAvis, pandas-profiling, mlxtend, mlflow, lightgbm, kmodes, imbalanced-learn, cufflinks, catboost, pycaret
# Successfully installed Mako-1.2.1 alembic-1.8.1 blis-0.7.8 catalogue-2.0.7 catboost-1.0.6 colorlover-0.3.0 cufflinks-0.17.3 cymem-2.0.6 databricks-cli-0.17.0 docker-5.0.3 funcy-1.17 gitdb-4.0.9 gitpython-3.1.27 graphviz-0.20 htmlmin-0.1.12 imagehash-4.2.1 imbalanced-learn-0.9.1 kmodes-0.12.1 langcodes-3.3.0 lightgbm-3.3.2 markupsafe-2.1.1 missingno-0.5.1 mlflow-1.27.0 mlxtend-0.20.0 multimethod-1.8 murmurhash-1.0.7 oauthlib-3.2.0 pandas-profiling-3.2.0 pathy-0.6.2 phik-0.12.2 preshed-3.0.6 prometheus-flask-exporter-0.20.2 pyLDAvis-3.3.1 pycaret-2.2.2 pydantic-1.9.1 pynndescent-0.5.7 pyod-1.0.3 pywin32-227 querystring-parser-1.2.4 scikit-learn-1.1.1 scikit-plot-0.3.7 sklearn-0.0 smart-open-5.2.1 smmap-5.0.0 spacy-3.4.0 spacy-legacy-3.0.9 spacy-loggers-1.0.3 sqlparse-0.4.2 srsly-2.4.3 tangled-up-in-unicode-0.2.0 textblob-0.17.1 thinc-8.1.0 typer-0.4.2 umap-learn-0.5.3 visions-0.7.4 waitress-2.1.2 wasabi-0.9.1 wordcloud-1.8.2.2 xgboost-1.6.1 yellowbrick-1.4
#     blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\behlul\AppData\Local\Temp\pip-install-ip7k67it\numpy_3c1761cf807d41e68fb35567d6951357\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\behlul\AppData\Local\Temp\pip-install-ip7k67it\numpy_3c1761cf807d41e68fb35567d6951357\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     'svnversion' is not recognized as an internal or external command,
#     operable program or batch file.
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas,lapack not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     flame_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries flame not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in c:\ProgramData\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in c:\ProgramData\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in c:\ProgramData\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in c:\ProgramData\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in c:\ProgramData\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\behlul\AppData\Local\Temp\pip-install-ip7k67it\numpy_3c1761cf807d41e68fb35567d6951357\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\behlul\AppData\Local\Temp\pip-install-ip7k67it\numpy_3c1761cf807d41e68fb35567d6951357\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#       NOT AVAILABLE
#
#     c:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running bdist_wheel
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     creating build
#     creating build\src.win-amd64-3.9
#     creating build\src.win-amd64-3.9\numpy
#     creating build\src.win-amd64-3.9\numpy\distutils
#     building library "npymath" sources
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
#     ERROR: Failed building wheel for numpy
#     Running setup.py clean for numpy
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\ProgramData\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-ip7k67it\\numpy_3c1761cf807d41e68fb35567d6951357\\setup.py'"'"'; __file__='"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-ip7k67it\\numpy_3c1761cf807d41e68fb35567d6951357\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#          cwd: C:\Users\behlul\AppData\Local\Temp\pip-install-ip7k67it\numpy_3c1761cf807d41e68fb35567d6951357
#     Complete output (10 lines):
#     Running from numpy source directory.
#
#     `setup.py clean` is not supported, use one of the following instead:
#
#       - `git clean -xdf` (cleans all files)
#       - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                           files that aren't checked into the git repo)
#
#     Add `--force` to your command to use it anyway if you must (unsupported).
#
#     ----------------------------------------
#     ERROR: Failed cleaning build dir for numpy
#   Failed to build numpy
#   Installing collected packages: numpy, wheel, setuptools, scipy, Cython
#       Running setup.py install for numpy: started
#       Running setup.py install for numpy: finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'c:\ProgramData\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-ip7k67it\\numpy_3c1761cf807d41e68fb35567d6951357\\setup.py'"'"'; __file__='"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-ip7k67it\\numpy_3c1761cf807d41e68fb35567d6951357\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\behlul\AppData\Local\Temp\pip-record-dw8oh1ul\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\behlul\AppData\Local\Temp\pip-build-env-3hvie57p\overlay' --compile --install-headers 'C:\Users\behlul\AppData\Local\Temp\pip-build-env-3hvie57p\overlay\Include\numpy'
#            cwd: C:\Users\behlul\AppData\Local\Temp\pip-install-ip7k67it\numpy_3c1761cf807d41e68fb35567d6951357\
#       Complete output (275 lines):
#       Running from numpy source directory.
#
#       Note: if you need reliable uninstall behavior, then install
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install numpy`   (last NumPy release on PyPi)
#
#
#       blas_opt_info:
#       blas_mkl_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries mkl_rt not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       blis_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries blis not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#       get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#       customize GnuFCompiler
#       Could not locate executable g77
#       Could not locate executable f77
#       customize IntelVisualFCompiler
#       Could not locate executable ifort
#       Could not locate executable ifl
#       customize AbsoftFCompiler
#       Could not locate executable f90
#       customize CompaqVisualFCompiler
#       Could not locate executable DF
#       customize IntelItaniumVisualFCompiler
#       Could not locate executable efl
#       customize Gnu95FCompiler
#       Could not locate executable gfortran
#       Could not locate executable f95
#       customize G95FCompiler
#       Could not locate executable g95
#       customize IntelEM64VisualFCompiler
#       customize IntelEM64TFCompiler
#       Could not locate executable efort
#       Could not locate executable efc
#       customize PGroupFlangCompiler
#       Could not locate executable flang
#       don't know how to compile Fortran code on platform 'nt'
#         NOT AVAILABLE
#
#       atlas_3_10_blas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       accelerate_info:
#         NOT AVAILABLE
#
#       C:\Users\behlul\AppData\Local\Temp\pip-install-ip7k67it\numpy_3c1761cf807d41e68fb35567d6951357\numpy\distutils\system_info.py:690: UserWarning:
#           Optimized (vendor) Blas libraries are not found.
#           Falls back to netlib Blas library which has worse performance.
#           A better performance should be easily gained by switching
#           Blas library.
#         self.calc_info()
#       blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries blas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\behlul\AppData\Local\Temp\pip-install-ip7k67it\numpy_3c1761cf807d41e68fb35567d6951357\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         self.calc_info()
#       blas_src_info:
#         NOT AVAILABLE
#
#       C:\Users\behlul\AppData\Local\Temp\pip-install-ip7k67it\numpy_3c1761cf807d41e68fb35567d6951357\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         self.calc_info()
#         NOT AVAILABLE
#
#       'svnversion' is not recognized as an internal or external command,
#       operable program or batch file.
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       lapack_opt_info:
#       lapack_mkl_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries mkl_rt not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_lapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_clapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas,lapack not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       flame_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries flame not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in c:\ProgramData\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#         NOT AVAILABLE
#
#       atlas_3_10_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in c:\ProgramData\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_info'>
#         NOT AVAILABLE
#
#       atlas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in c:\ProgramData\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_threads_info'>
#         NOT AVAILABLE
#
#       atlas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in c:\ProgramData\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in c:\ProgramData\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in c:\ProgramData\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_info'>
#         NOT AVAILABLE
#
#       lapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack not found in ['c:\\ProgramData\\Anaconda3\\lib', 'C:\\', 'c:\\ProgramData\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\behlul\AppData\Local\Temp\pip-install-ip7k67it\numpy_3c1761cf807d41e68fb35567d6951357\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#       lapack_src_info:
#         NOT AVAILABLE
#
#       C:\Users\behlul\AppData\Local\Temp\pip-install-ip7k67it\numpy_3c1761cf807d41e68fb35567d6951357\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#         NOT AVAILABLE
#
#       c:\ProgramData\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running install
#       c:\ProgramData\Anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running config_cc
#       unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       build_src
#       building py_modules sources
#       building library "npymath" sources
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#   ERROR: Command errored out with exit status 1: 'c:\ProgramData\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-ip7k67it\\numpy_3c1761cf807d41e68fb35567d6951357\\setup.py'"'"'; __file__='"'"'C:\\Users\\behlul\\AppData\\Local\\Temp\\pip-install-ip7k67it\\numpy_3c1761cf807d41e68fb35567d6951357\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\behlul\AppData\Local\Temp\pip-record-dw8oh1ul\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\behlul\AppData\Local\Temp\pip-build-env-3hvie57p\overlay' --compile --install-headers 'C:\Users\behlul\AppData\Local\Temp\pip-build-env-3hvie57p\overlay\Include\numpy' Check the logs for full command output.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/aa/f6/75297be19f48b7a8c2577753a3a700f98fc4db49d0e5ed3820dd8dee43d4/scikit-learn-0.23.2.tar.gz#sha256=20766f515e6cd6f954554387dfae705d93c7b544ec0e6c6a5d8e006f6f7ef480 (from https://pypi.org/simple/scikit-learn/) (requires-python:>=3.6). Command errored out with exit status 1: 'c:\ProgramData\Anaconda3\python.exe' 'C:\Users\behlul\AppData\Local\Temp\pip-standalone-pip-6ju1qln6\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\behlul\AppData\Local\Temp\pip-build-env-3hvie57p\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1' Check the logs for full command output.
#   WARNING: The script mako-render.exe is installed in 'C:\Users\behlul\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script waitress-serve.exe is installed in 'C:\Users\behlul\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script sqlformat.exe is installed in 'C:\Users\behlul\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script phik_trial.exe is installed in 'C:\Users\behlul\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pathy.exe is installed in 'C:\Users\behlul\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script htmlmin.exe is installed in 'C:\Users\behlul\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts databricks.exe and dbfs.exe are installed in 'C:\Users\behlul\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script alembic.exe is installed in 'C:\Users\behlul\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\behlul\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script spacy.exe is installed in 'C:\Users\behlul\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pandas_profiling.exe is installed in 'C:\Users\behlul\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts mlflow.exe and mlp.exe are installed in 'C:\Users\behlul\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.

# %%
pip install pycaret-ts-alpha
# Out:
# Collecting pycaret-ts-alpha
#   Downloading pycaret_ts_alpha-3.0.0.dev1649017462-py3-none-any.whl (468 kB)
# Collecting yellowbrick>=1.4
#   Using cached yellowbrick-1.4-py3-none-any.whl (274 kB)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\programdata\anaconda3\lib\site-packages (from pycaret-ts-alpha) (1.0.2)
# Requirement already satisfied: scipy~=1.7.3 in c:\programdata\anaconda3\lib\site-packages (from pycaret-ts-alpha) (1.7.3)
# Collecting imbalanced-learn>=0.8.1
#   Using cached imbalanced_learn-0.9.1-py3-none-any.whl (199 kB)
# Collecting joblib~=1.0.1
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
# Collecting scikit-plot>=0.3.7
#   Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\programdata\anaconda3\lib\site-packages (from pycaret-ts-alpha) (3.5.1)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\programdata\anaconda3\lib\site-packages (from pycaret-ts-alpha) (0.13.2)
# Requirement already satisfied: plotly>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from pycaret-ts-alpha) (5.6.0)
# Collecting pyod>=0.9.8
#   Using cached pyod-1.0.3-py3-none-any.whl
# Requirement already satisfied: numba~=0.55.0 in c:\programdata\anaconda3\lib\site-packages (from pycaret-ts-alpha) (0.55.1)
# Collecting pmdarima>=1.8.0
#   Downloading pmdarima-1.8.5-cp39-cp39-win_amd64.whl (601 kB)
# Collecting kaleido>=0.2.1
#   Downloading kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
# Collecting tbats>=1.1.0
#   Downloading tbats-1.1.0-py3-none-any.whl (43 kB)
# Requirement already satisfied: pandas<1.5.0,>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from pycaret-ts-alpha) (1.4.2)
# Requirement already satisfied: numpy~=1.21 in c:\programdata\anaconda3\lib\site-packages (from pycaret-ts-alpha) (1.21.5)
# Collecting category-encoders>=2.4.0
#   Downloading category_encoders-2.5.0-py2.py3-none-any.whl (69 kB)
# Collecting lightgbm>=3.0.0
#   Using cached lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
# Collecting sktime==0.10.1
#   Downloading sktime-0.10.1-py3-none-any.whl (6.5 MB)
# Requirement already satisfied: ipython>=5.5.0 in c:\programdata\anaconda3\lib\site-packages (from pycaret-ts-alpha) (8.2.0)
# Collecting deprecated>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: patsy>=0.5.1 in c:\programdata\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret-ts-alpha) (0.5.2)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\programdata\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime==0.10.1->pycaret-ts-alpha) (1.12.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret-ts-alpha) (2.2.0)
# Collecting scikit-learn>=1.0.2
#   Using cached scikit_learn-1.1.1-cp39-cp39-win_amd64.whl (7.4 MB)
# Requirement already satisfied: matplotlib-inline in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret-ts-alpha) (0.1.2)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret-ts-alpha) (0.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret-ts-alpha) (0.3.9)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret-ts-alpha) (3.0.20)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret-ts-alpha) (5.1.1)
# Requirement already satisfied: traitlets>=5 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret-ts-alpha) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret-ts-alpha) (2.11.2)
# Requirement already satisfied: stack-data in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret-ts-alpha) (0.2.0)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret-ts-alpha) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret-ts-alpha) (61.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret-ts-alpha) (0.18.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret-ts-alpha) (0.8.3)
# Requirement already satisfied: wheel in c:\programdata\anaconda3\lib\site-packages (from lightgbm>=3.0.0->pycaret-ts-alpha) (0.37.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret-ts-alpha) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret-ts-alpha) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret-ts-alpha) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret-ts-alpha) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret-ts-alpha) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret-ts-alpha) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret-ts-alpha) (21.3)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\programdata\anaconda3\lib\site-packages (from numba~=0.55.0->pycaret-ts-alpha) (0.38.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<1.5.0,>=1.3.0->pycaret-ts-alpha) (2021.3)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret-ts-alpha) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from plotly>=5.0.0->pycaret-ts-alpha) (8.0.1)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from pmdarima>=1.8.0->pycaret-ts-alpha) (1.26.9)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in c:\programdata\anaconda3\lib\site-packages (from pmdarima>=1.8.0->pycaret-ts-alpha) (0.29.28)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret-ts-alpha) (0.2.5)
# Requirement already satisfied: pure-eval in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret-ts-alpha) (0.2.2)
# Requirement already satisfied: asttokens in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret-ts-alpha) (2.0.5)
# Requirement already satisfied: executing in c:\programdata\anaconda3\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret-ts-alpha) (0.8.3)
# Installing collected packages: joblib, scikit-learn, pmdarima, deprecated, yellowbrick, tbats, sktime, scikit-plot, pyod, lightgbm, kaleido, imbalanced-learn, category-encoders, pycaret-ts-alpha
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Erişim engellendi: 'c:\\programdata\\anaconda3\\lib\\site-packages\\joblib-1.1.0.dist-info\\direct_url.json'
# Consider using the `--user` option or check the permissions.

# %%
import pandas as pd

# %%
from pycaret.regression import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\behlul\makina ogrenmesi\11. gun\11. gun zip\kcev.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/behlul/makina%20ogrenmesi/11.%20gun/11.%20gun%20zip/kcev.ipynb#ch0000002?line=0'>1</a> from pycaret.regression import *
#
# ModuleNotFoundError: No module named 'pycaret'

# %%
df=pd.read_pickle('kc_house.pkl')

# %%
exp_name=setup(data=df, target='price')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\behlul\makina ogrenmesi\11. gun\11. gun zip\kcev.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/behlul/makina%20ogrenmesi/11.%20gun/11.%20gun%20zip/kcev.ipynb#ch0000004?line=0'>1</a> exp_name=setup(data=df, target='price')
#
# NameError: name 'setup' is not defined

# %%
best_model=compare_models()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\behlul\makina ogrenmesi\11. gun\11. gun zip\kcev.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/behlul/makina%20ogrenmesi/11.%20gun/11.%20gun%20zip/kcev.ipynb#ch0000005?line=0'>1</a> best_model=compare_models()
#
# NameError: name 'compare_models' is not defined

# %%
df=pd.read_excel('cars.xls')

# %%
x=df[['Price','Mileage','Cylinder']]

# %%
from pycaret.clustering import *
clul=setup(df,session_id=123,log_experiment=True,log_plots=True,experiment_name='Cars Clustering')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\behlul\makina ogrenmesi\11. gun\11. gun zip\kcev.ipynb Cell 10' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/behlul/makina%20ogrenmesi/11.%20gun/11.%20gun%20zip/kcev.ipynb#ch0000009?line=0'>1</a> from pycaret.clustering import *
#       <a href='vscode-notebook-cell:/c%3A/Users/behlul/makina%20ogrenmesi/11.%20gun/11.%20gun%20zip/kcev.ipynb#ch0000009?line=1'>2</a> clul=setup(df,session_id=123,log_experiment=True,log_plots=True,experiment_name='Cars Clustering')
#
# ModuleNotFoundError: No module named 'pycaret'

# %%
kmeans=create_model('kmeans',num_clusters=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\behlul\makina ogrenmesi\11. gun\11. gun zip\kcev.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/behlul/makina%20ogrenmesi/11.%20gun/11.%20gun%20zip/kcev.ipynb#ch0000010?line=0'>1</a> kmeans=create_model('kmeans',num_clusters=4)
#
# NameError: name 'create_model' is not defined

# %%
plot_model(kmeans)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\behlul\makina ogrenmesi\11. gun\11. gun zip\kcev.ipynb Cell 13' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/behlul/makina%20ogrenmesi/11.%20gun/11.%20gun%20zip/kcev.ipynb#ch0000012?line=0'>1</a> plot_model(kmeans)
#
# NameError: name 'plot_model' is not defined

# %%
plot_model(kmeans,feature='Cylinder',label=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\behlul\makina ogrenmesi\11. gun\11. gun zip\kcev.ipynb Cell 14' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/behlul/makina%20ogrenmesi/11.%20gun/11.%20gun%20zip/kcev.ipynb#ch0000013?line=0'>1</a> plot_model(kmeans,feature='Cylinder',label=True)
#
# NameError: name 'plot_model' is not defined

# %%
plot_model(kmeans,plot='tsne')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\behlul\makina ogrenmesi\11. gun\11. gun zip\kcev.ipynb Cell 15' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/behlul/makina%20ogrenmesi/11.%20gun/11.%20gun%20zip/kcev.ipynb#ch0000014?line=0'>1</a> plot_model(kmeans,plot='tsne')
#
# NameError: name 'plot_model' is not defined
