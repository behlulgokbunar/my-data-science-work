# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
scaler = StandardScaler()
import pandas_profiling
from datetime import datetime
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, recall_score, precision_score
from sklearn.model_selection import StratifiedKFold
from imblearn.metrics import geometric_mean_score as geo
from imblearn.metrics import make_index_balanced_accuracy as iba
from sklearn.metrics import roc_curve, auc
from imblearn.metrics import geometric_mean_score, make_index_balanced_accuracy, classification_report_imbalanced
from pycaret.regression import *
import sqlite3
from sqlite3 import Error
import datetime as dt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split as tts
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.feature_selection import SelectKBest, mutual_info_regression, VarianceThreshold
from sklearn.preprocessing import StandardScaler, OrdinalEncoder

# %%
df1=pd.read_csv('train.csv')

# %%
df2=pd.read_csv('test.csv')

# %%
df1.info(40)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4209 entries, 0 to 4208
# Data columns (total 378 columns):
#  #    Column  Dtype
# ---   ------  -----
#  0    ID      int64
#  1    y       float64
#  2    X0      object
#  3    X1      object
#  4    X2      object
#  5    X3      object
#  6    X4      object
#  7    X5      object
#  8    X6      object
#  9    X8      object
#  10   X10     int64
#  11   X11     int64
#  12   X12     int64
#  13   X13     int64
#  14   X14     int64
#  15   X15     int64
#  16   X16     int64
#  17   X17     int64
#  18   X18     int64
#  19   X19     int64
#  20   X20     int64
#  21   X21     int64
#  22   X22     int64
#  23   X23     int64
#  24   X24     int64
#  25   X26     int64
#  26   X27     int64
#  27   X28     int64
#  28   X29     int64
#  29   X30     int64
#  30   X31     int64
#  31   X32     int64
#  32   X33     int64
#  33   X34     int64
#  34   X35     int64
#  35   X36     int64
#  36   X37     int64
# ...

# %%
df1.isnull().sum()
# Out:
# ID      0
# y       0
# X0      0
# X1      0
# X2      0
# X3      0
# X4      0
# X5      0
# X6      0
# X8      0
# X10     0
# X11     0
# X12     0
# X13     0
# X14     0
# X15     0
# X16     0
# X17     0
# X18     0
# X19     0
# X20     0
# X21     0
# X22     0
# X23     0
# X24     0
# X26     0
# X27     0
# X28     0
# X29     0
# X30     0
# X31     0
# X32     0
# X33     0
# X34     0
# X35     0
# X36     0
# X37     0
# X38     0
# X39     0
# X40     0
# X41     0
# X42     0
# X43     0
# X44     0
# X45     0
# X46     0
# X47     0
# X48     0
# X49     0
# X50     0
# X51     0
# X52     0
# X53     0
# X54     0
# X55     0
# X56     0
# X57     0
# X58     0
# X59     0
# X60     0
# X61     0
# X62     0
# X63     0
# X64     0
# X65     0
# X66     0
# X67     0
# X68     0
# X69     0
# X70     0
# X71     0
# X73     0
# X74     0
# X75     0
# X76     0
# X77     0
# X78     0
# X79     0
# X80     0
# X81     0
# X82     0
# X83     0
# X84     0
# ...

# %%
df1.astype('object').dtypes
# Out:
# ID      object
# y       object
# X0      object
# X1      object
# X2      object
# X3      object
# X4      object
# X5      object
# X6      object
# X8      object
# X10     object
# X11     object
# X12     object
# X13     object
# X14     object
# X15     object
# X16     object
# X17     object
# X18     object
# X19     object
# X20     object
# X21     object
# X22     object
# X23     object
# X24     object
# X26     object
# X27     object
# X28     object
# X29     object
# X30     object
# X31     object
# X32     object
# X33     object
# X34     object
# X35     object
# X36     object
# X37     object
# X38     object
# X39     object
# X40     object
# X41     object
# X42     object
# X43     object
# X44     object
# X45     object
# X46     object
# X47     object
# X48     object
# X49     object
# X50     object
# X51     object
# X52     object
# X53     object
# X54     object
# X55     object
# X56     object
# X57     object
# X58     object
# ...

# %% [markdown]
# df_dummies=pd.get_dummies(df1,drop_first=True)

# %% [markdown]
# df_dummies2=pd.get_dummies(df2,drop_first=True)

# %% [markdown]
# abs(df_dummies.corr()['y']).sort_values(ascending=False)

# %% [markdown]
# y=df_dummies['y']
# x=df_dummies.drop(['y','ID'],axis=1)

# %% [markdown]
# x_test2=df_dummies2.drop(['ID'], axis = 1)

# %% [markdown]
# y=df1['y']
# x=df1.drop(['y','ID'],axis=1)

# %% [markdown]
# x_test=df2.drop(['ID'], axis = 1)

# %% [markdown]
# numerical_features = x.select_dtypes(include = 'number').columns.values
# numerical_features

# %% [markdown]
# categorical_features = x.select_dtypes(exclude = 'number').columns.values
# categorical_features

# %% [markdown]
# x_train,x_val,y_train,y_val=tts(x,y,test_size=0.2)

# %% [markdown]
# enc_oe = OrdinalEncoder(handle_unknown = 'use_encoded_value', unknown_value = np.NaN)

# %% [markdown]
# enc_oe.fit(x_train[categorical_features])
# x_train[categorical_features] = enc_oe.transform(x_train[categorical_features])
# x_test[categorical_features] = enc_oe.transform(x_test[categorical_features])
# x_val[categorical_features] = enc_oe.transform(x_val[categorical_features])

# %% [markdown]
# selector = SelectKBest(mutual_info_regression, k = 30)

# %% [markdown]
# selector.fit(x_train, y_train)
# x_train = selector.transform(x_train)
# x_test = selector.transform(x_test)
# x_val = selector.transform(x_val)

# %% [markdown]
# scaler = StandardScaler()

# %% [markdown]
# scaler.fit(x_train, y_train)
# x_train = scaler.transform(x_train)
# x_test = scaler.transform(x_test)
# x_val = scaler.transform(x_val)

# %%
reg = setup(data=df1, target='y',imputation_type='iterative',fold_shuffle=True)

# %%
models = compare_models()
# Out:
# <style type="text/css">
# #T_6cf21 th {
#   text-align: left;
# }
# ...

# %%
omp=create_model('omp')
# Out:
# <style type="text/css">
# #T_1885e_row10_col0, #T_1885e_row10_col1, #T_1885e_row10_col2, #T_1885e_row10_col3, #T_1885e_row10_col4, #T_1885e_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_1885e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1885e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_1885e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1885e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_1885e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1885e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_1885e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1885e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1885e_row0_col0" class="data row0 col0" >5.0924</td>
# ...

# %%
tune_omp=tune_model(omp)
# Out:
# <style type="text/css">
# #T_52194_row10_col0, #T_52194_row10_col1, #T_52194_row10_col2, #T_52194_row10_col3, #T_52194_row10_col4, #T_52194_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_52194">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52194_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_52194_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_52194_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_52194_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_52194_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_52194_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52194_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52194_row0_col0" class="data row0 col0" >5.0316</td>
# ...

# %%
br=create_model('br')
# Out:
# <style type="text/css">
# #T_d4a65_row10_col0, #T_d4a65_row10_col1, #T_d4a65_row10_col2, #T_d4a65_row10_col3, #T_d4a65_row10_col4, #T_d4a65_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d4a65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4a65_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d4a65_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d4a65_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d4a65_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d4a65_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d4a65_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4a65_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4a65_row0_col0" class="data row0 col0" >5.0470</td>
# ...

# %%
tune_br=tune_model(br)
# Out:
# <style type="text/css">
# #T_6381d_row10_col0, #T_6381d_row10_col1, #T_6381d_row10_col2, #T_6381d_row10_col3, #T_6381d_row10_col4, #T_6381d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6381d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6381d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6381d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6381d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6381d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6381d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_6381d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6381d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6381d_row0_col0" class="data row0 col0" >5.0468</td>
# ...

# %%
gbr=create_model('gbr')
# Out:
# <style type="text/css">
# #T_7abe8_row10_col0, #T_7abe8_row10_col1, #T_7abe8_row10_col2, #T_7abe8_row10_col3, #T_7abe8_row10_col4, #T_7abe8_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7abe8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7abe8_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7abe8_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7abe8_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7abe8_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7abe8_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7abe8_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7abe8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7abe8_row0_col0" class="data row0 col0" >5.0057</td>
# ...

# %%
tune_gbr=tune_model(gbr)
# Out:
# <style type="text/css">
# #T_11153_row10_col0, #T_11153_row10_col1, #T_11153_row10_col2, #T_11153_row10_col3, #T_11153_row10_col4, #T_11153_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_11153">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11153_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_11153_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_11153_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_11153_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_11153_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_11153_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11153_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11153_row0_col0" class="data row0 col0" >5.0676</td>
# ...

# %%
stacked=stack_models(estimator_list=[tune_omp,tune_br],meta_model=tune_gbr,restack=False)
# Out:
# <style type="text/css">
# #T_14fdd_row10_col0, #T_14fdd_row10_col1, #T_14fdd_row10_col2, #T_14fdd_row10_col3, #T_14fdd_row10_col4, #T_14fdd_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_14fdd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14fdd_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_14fdd_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_14fdd_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_14fdd_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_14fdd_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_14fdd_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14fdd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14fdd_row0_col0" class="data row0 col0" >4.9895</td>
# ...

# %%
predictions=predict_model(stacked,data=df2)
predictions.head()
# Out:
#    ID  X0 X1  X2 X3 X4 X5 X6 X8  X10  ...  X376  X377  X378  X379  X380  X382  \
# 0   1  az  v   n  f  d  t  a  w    0  ...     0     0     1     0     0     0
# 1   2   t  b  ai  a  d  b  g  y    0  ...     0     1     0     0     0     0
# 2   3  az  v  as  f  d  a  j  j    0  ...     0     0     1     0     0     0
# 3   4  az  l   n  f  d  z  l  n    0  ...     0     0     1     0     0     0
# 4   5   w  s  as  c  d  y  i  m    0  ...     0     0     0     0     0     0
#
#    X383  X384  X385       Label
# 0     0     0     0   78.289285
# 1     0     0     0   94.072549
# 2     0     0     0   78.289285
# 3     0     0     0   77.221336
# 4     0     0     0  113.083785
#
# [5 rows x 378 columns]

# %%
sample_submission=pd.read_csv('sample_submission.csv')

# %%
sample_submission['y']=predictions['Label']
sample_submission.to_csv('submission.csv',index=False)

# %% [markdown]
# GBR=GradientBoostingRegressor()
# GBR.fit(x_train,y_train)
# y_pred_gbr=GBR.predict(x_train)

# %% [markdown]
# GBR.score(y_train, y_pred_gbr)

# %% [markdown]
# y_pred_gbr2=GBR.predict(x_test)

# %% [markdown]
# submission = pd.DataFrame({
#     'ID' : df2['ID'],
#     'y' : y_pred_gbr2
# })
#
# submission.head()

# %% [markdown]
# submission.to_csv('submission.csv', index = False)

# %% [markdown]
# data=df1.drop(['ID'],axis=1)

# %% [markdown]
# exp_name=setup(data=data,target='y',fold_shuffle=True)

# %% [markdown]
# best_model=compare_models()
