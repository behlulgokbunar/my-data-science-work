# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',100)
import warnings
warnings.filterwarnings("ignore")
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
source1=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE').text
source2=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=2').text
source3=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=3').text
source4=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=4').text
source5=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=5').text
source6=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=6').text
source7=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=7').text
source8=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=8').text
source9=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=9').text
source10=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=10').text
source11=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=11').text
source12=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=12').text
source13=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=13').text
source14=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=14').text
source15=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=15').text
source16=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=16').text
source17=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=17').text
source18=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=18').text
source19=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=19').text
source20=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=20').text
source21=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=21').text
source22=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=22').text
source23=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=23').text
source24=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=24').text
source25=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=25').text
source26=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=26').text
source27=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=27').text
source28=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=28').text
source29=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=29').text
source30=requests.get('https://www.hepsiemlak.com/istanbul-kiralik?sortDirection=DESC&sortField=UPDATED_DATE?page=30').text
source=

# %%
soup=BeautifulSoup(source,'html.parser')

# %%
soup.beautify

# %%
container=soup.find_all("ul",{"class":"list-items-container"})

# %%
fiyat=soup.findAll("span",{"class":"list-view-price"})
yas=soup.findAll("span",{"class":"celly buildingAge"})
kat=soup.findAll("span",{"class":"celly floortype"})
boyut=soup.findAll("span",{"class":"celly houseRoomCount"})
alan=soup.findAll("span",{"class":"celly squareMeter list-view-size"})
location = soup.findAll("div", {"class" : "list-view-location"})

# %%
f=[]
y=[]
k=[]
b=[]
a=[]
l=[]

# %%
for span in fiyat:
    print(span.text)
    f.append(span.text)
# Out:
#               6.650
#               TL
#
#               9.250
#               TL
#
#               5.200
#               TL
#
#               49.500
#               TL
#
#               50.000
#               TL
#
#               12.000
#               TL
#
#               12.000
#               TL
#
#               16.500
#               TL
#
#               17.000
#               TL
#
#               16.000
#               TL
#
#               20.000
#               TL
#
#               25.000
#               TL
#
#               13.000
#               TL
#
#               18.000
#               TL
#
#               7.000
#               TL
#
#               12.000
#               TL
#
#               5.750
#               TL
#
#               8.000
#               TL
#
#               10.000
#               TL
#
#               5.000
#               TL
#
#               6.000
#               TL
#
#               15.000
#               TL
#
#               75.000
# ...

# %%
for span in yas:
    print(span.text)
    y.append(span.text)
# Out:
# 20 Yaşında
# 26 Yaşında
# 18 Yaşında
# 11 Yaşında
# 5 Yaşında
# 32 Yaşında
# 32 Yaşında
# 25 Yaşında
# 11 Yaşında
# 1 Yaşında
# 10 Yaşında
# 40 Yaşında
# 30 Yaşında
# 30 Yaşında
# 30 Yaşında
# 30 Yaşında
# 10 Yaşında
# 23 Yaşında
# 23 Yaşında
# 15 Yaşında
# 16 Yaşında
# 23 Yaşında
# 20 Yaşında
# 23 Yaşında
# 20 Yaşında
# 26 Yaşında
# 18 Yaşında
# 11 Yaşında
# 5 Yaşında
# 32 Yaşında
# 32 Yaşında
# 25 Yaşında
# 11 Yaşında
# 1 Yaşında
# 10 Yaşında
# 40 Yaşında
# 30 Yaşında
# 30 Yaşında
# 30 Yaşında
# 30 Yaşında
# 10 Yaşında
# 23 Yaşında
# 23 Yaşında
# 15 Yaşında
# 16 Yaşında
# 23 Yaşında
# 20 Yaşında
# 23 Yaşında
# 20 Yaşında
# 26 Yaşında
# 18 Yaşında
# 11 Yaşında
# 5 Yaşında
# 32 Yaşında
# 32 Yaşında
# 25 Yaşında
# 11 Yaşında
# 1 Yaşında
# 10 Yaşında
# 40 Yaşında
# 30 Yaşında
# 30 Yaşında
# 30 Yaşında
# 30 Yaşında
# 10 Yaşında
# 23 Yaşında
# 23 Yaşında
# 15 Yaşında
# 16 Yaşında
# 23 Yaşında
# 20 Yaşında
# 23 Yaşında
# 20 Yaşında
# 26 Yaşında
# 18 Yaşında
# 11 Yaşında
# 5 Yaşında
# ...

# %%
for span in kat:
    print(span.text)
    k.append(span.text)
# Out:
#                       1. Kat
#
#                       2. Kat
#
#                       2. Kat
#
#                       Villa Katı
#
#                       Villa Katı
#
#                       11. Kat
#
#                       4. Kat
#
#                       5. Kat
#
#                       9. Kat
#
#                       5. Kat
#
#                       4. Kat
#
#                       7. Kat
#
#                       6. Kat
#
#                       1. Kat
#
#                       Kot 1
#
#
#
#                       Giriş Katı
#
#                       3. Kat
#
#                       Yüksek Giriş
#
#                       5. Kat
#
#                       1. Kat
#
#                       Yüksek Giriş
#
#                       Ara Kat
#
#                       11. Kat
#
#                       1. Kat
#
#                       2. Kat
#
#                       2. Kat
#
#                       Villa Katı
#
#                       Villa Katı
#
#                       11. Kat
#
# ...

# %%
for span in boyut:
    print(span.text)
    b.append(span.text)
# Out:
# 2 + 1
# 3 + 1
# 3 + 1
# 5 + 2
# 6 + 2
# 3 + 1
# 3 + 1
# 1 + 1
# 1 + 1
# 2 + 1
# 1 + 1
# 2 + 1
# 2 + 1
# 2 + 1
# 2 + 1
# 4 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 5 + 1
# 1 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 5 + 2
# 6 + 2
# 3 + 1
# 3 + 1
# 1 + 1
# 1 + 1
# 2 + 1
# 1 + 1
# 2 + 1
# 2 + 1
# 2 + 1
# 2 + 1
# 4 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 5 + 1
# 1 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 5 + 2
# 6 + 2
# 3 + 1
# 3 + 1
# 1 + 1
# 1 + 1
# 2 + 1
# 1 + 1
# 2 + 1
# 2 + 1
# 2 + 1
# 2 + 1
# 4 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 5 + 1
# 1 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 5 + 2
# 6 + 2
# 3 + 1
# 3 + 1
# 1 + 1
# 1 + 1
# 2 + 1
# 1 + 1
# 2 + 1
# 2 + 1
# 2 + 1
# 2 + 1
# 4 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 5 + 1
# 1 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 5 + 2
# 6 + 2
# 3 + 1
# 3 + 1
# 1 + 1
# 1 + 1
# 2 + 1
# 1 + 1
# 2 + 1
# 2 + 1
# 2 + 1
# 2 + 1
# 4 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 5 + 1
# 1 + 1
# 2 + 1
# 3 + 1
# 3 + 1
# 5 + 2
# 6 + 2
# ...

# %%
for span in alan:
    print(span.text)
    a.append(span.text)
# Out:
#                           85 m2
#
#                           130 m2
#
#                           120 m2
#
#                           380 m2
#
#                           350 m2
#
#                           140 m2
#
#                           145 m2
#
#                           75 m2
#
#                           85 m2
#
#                           92 m2
#
#                           70 m2
#
#                           100 m2
#
#                           100 m2
#
#                           100 m2
#
#                           90 m2
#
#                           250 m2
#
#                           90 m2
#
#                           125 m2
#
#                           141 m2
#
#                           151 m2
#
#                           140 m2
#
#                           172 m2
#
#                           450 m2
#
#                           62 m2
#
#                           85 m2
#
#                           130 m2
#
#                           120 m2
#
# ...

# %%
for span in location:
    print(span.text)
    l.append(span.text)
# Out:
#                       Fatih,
#
#                       Seyyid Ömer Mahallesi
#
#
#                       Kadıköy,
#
#                       Bostancı Mahallesi
#
#
#                       Ümraniye,
#
#                       Namık Kemal Mahallesi
#
#
#                       Sarıyer,
#
#                       Zekeriyaköy Mahallesi
#
#
#                       Sarıyer,
#
#                       Uskumruköy Mahallesi
#
#
#                       Kadıköy,
#
#                       19 Mayıs Mahallesi
#
#
#                       Kadıköy,
#
#                       19 Mayıs Mahallesi
#
#
#                       Beyoğlu,
#
#                       Firuzağa Mahallesi
#
#
#                       Sarıyer,
#
#                       Maslak Mahallesi
#
#
#                       Kağıthane,
#
#                       Çeliktepe Mahallesi
#
#
#                       Şişli,
#
#                       Teşvikiye Mahallesi
#
#
#                       Beşiktaş,
#
#                       Etiler Mahallesi
#
#
# ...

# %%
d={'fiyat':f,'yas':y,'kat':k,'boyut':b,'alan':a,'location':l}#,'location':l
df=pd.DataFrame(d)
df
# Out:
#                                         fiyat         yas  \
# 0     \n              6.650\n              TL  20 Yaşında
# 1     \n              9.250\n              TL  26 Yaşında
# 2     \n              5.200\n              TL  18 Yaşında
# 3    \n              49.500\n              TL  11 Yaşında
# 4    \n              50.000\n              TL   5 Yaşında
# ..                                        ...         ...
# 715   \n              5.000\n              TL  15 Yaşında
# 716   \n              6.000\n              TL  16 Yaşında
# 717  \n              15.000\n              TL  23 Yaşında
# 718  \n              75.000\n              TL  20 Yaşında
# 719   \n              5.000\n              TL  23 Yaşında
#
#                                       kat  boyut  \
# 0          \n                      1. Kat  2 + 1
# 1          \n                      2. Kat  3 + 1
# 2          \n                      2. Kat  3 + 1
# 3      \n                      Villa Katı  5 + 2
# ...

# %%
df['fiyat']=df['fiyat'].str.replace('\n','')
df['kat']=df['kat'].str.replace('\n','')
df['alan']=df['alan'].str.replace('\n','')
df['location']=df['location'].str.replace('\n','')
df['fiyat']=df['fiyat'].str.replace('TL','')
df['yas']=df['yas'].str.replace('Yaşında','')
df['yas']=df['yas'].str.replace('Sıfır Bina','0')
df['alan']=df['alan'].str.replace('m2','')
df['fiyat']=df['fiyat'].str.replace('.','')
df['location']=df['location'].str.replace(',','')
df['alan']=df['alan'].str.replace('.','')
df['fiyat']=df['fiyat'].astype(int)
df['yas']=df['yas'].astype(int)
df['alan']=df['alan'].astype(int)

# %%
df.to_csv('istanbul.csv')
df
# Out:
#      fiyat  yas                                 kat  boyut  alan  \
# 0     6650   20                              1. Kat  2 + 1    85
# 1     9250   26                              2. Kat  3 + 1   130
# 2     5200   18                              2. Kat  3 + 1   120
# 3    49500   11                          Villa Katı  5 + 2   380
# 4    50000    5                          Villa Katı  6 + 2   350
# ..     ...  ...                                 ...    ...   ...
# 715   5000   15                              5. Kat  2 + 1   151
# 716   6000   16                              1. Kat  3 + 1   140
# 717  15000   23                        Yüksek Giriş  3 + 1   172
# 718  75000   20                             Ara Kat  5 + 1   450
# 719   5000   23                             11. Kat  1 + 1    62
#
#                                               location
# 0                          Fatih                   ...
# 1                          Kadıköy                 ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fiyat     720 non-null    int32
#  1   yas       720 non-null    int32
#  2   kat       720 non-null    object
#  3   boyut     720 non-null    object
#  4   alan      720 non-null    int32
#  5   location  720 non-null    object
# dtypes: int32(3), object(3)
# memory usage: 25.4+ KB

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
x=df.drop('fiyat',axis=1)
y=df['fiyat']

# %%
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2,random_state=13)

# %%
lr=LinearRegression()
regmodel=lr.fit(x_train,y_train)

# %%
y_pretest=regmodel.predict(x_test)

# %%
(mean_squared_error(y_test,y_pretest))**0.5
# Out:
# 1.653082896447083e-11

# %%
r2_score(y_test,y_pretest)
# Out:
# 1.0

# %%
def algo_test(x,y):

        L=LinearRegression()
        R=Ridge()
        Lass=Lasso()
        E=ElasticNet()
        ETR=ExtraTreeRegressor()
        GBR=GradientBoostingRegressor()
        XGBC=XGBRegressor()
        dt=DecisionTreeRegressor()
        kn=KNeighborsRegressor()
        
        
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.1,random_state=13)
        
        algos=[L,R,Lass,E,ETR,GBR,XGBC,dt,kn]
        algo_names=['Linear','Ridge','Lasso','ElasticNet','Extra Tree','Gradient Boosting','XGradientBoosting','DecisionTree','KNeighbors']
        
        r2Score = []
        rmse = []
        mae = []
        
        result=pd.DataFrame(columns=['R2_score','RMSE','MAE'],index=algo_names)
        
        
        for algo in algos:
            p=algo.fit(x_train,y_train).predict(x_test)
            r2Score.append(r2_score(y_test,p))
            rmse.append(mean_squared_error(y_test,p)**.5)
            mae.append(mean_absolute_error(y_test,p))
        
            
        result['R2_score']=r2Score 
        result.RMSE=rmse
        result.MAE=mae


        return result.sort_values('R2_score',ascending=False)

# %%
from sklearn.model_selection import train_test_split
y=df[["fiyat"]]
x=df.drop(columns='fiyat',axis=1)

# %%
algo_test(x,y)
# Out:
#                    R2_score          RMSE           MAE
# Linear             1.000000  1.433717e-11  1.260661e-11
# Extra Tree         1.000000  0.000000e+00  0.000000e+00
# DecisionTree       1.000000  0.000000e+00  0.000000e+00
# KNeighbors         1.000000  0.000000e+00  0.000000e+00
# XGradientBoosting  1.000000  1.836923e-03  1.186795e-03
# Lasso              0.999990  4.938537e+01  3.320104e+01
# Ridge              0.999788  2.227004e+02  1.747257e+02
# Gradient Boosting  0.999696  2.666487e+02  2.497484e+02
# ElasticNet         0.794321  6.930670e+03  5.312902e+03

# %% [markdown]
# url="https://www.hepsiemlak.com/istanbul-kiralik"
# response = requests.get(url)

# %% [markdown]
# response.text

# %% [markdown]
# soup=BeautifulSoup(response.text, "html.parser")

# %% [markdown]
# soup.beautify

# %% [markdown]
# p_list, r_list, v_list, a_list, f_list, l_list = [], [], [], [], [], []
# for i in range(1, 461):
#     url = "https://www.hepsiemlak.com/istanbul-kiralik?page={}".format(i)
#     reponse = requests.get(url)
#     soup = BeautifulSoup(reponse.text, "html.parser")
#     soup.beautify
#     price = soup.findAll("div", {"class": "list-view-price"})
#     room = soup.findAll("span", {"class" : "houseRoomCount"})
#     viewsize = soup.findAll("span", {"class" : "list-view-size"})
#     age = soup.findAll("span", {"class" : "buildingAge"})
#     floortype =soup.findAll("span", {"class" : "floortype"})
#     location = soup.findAll("div", {"class" : "list-view-location"})
#     for (p1, r1, v1, a1, f1, l1) in zip(price, room, viewsize, age, floortype, location):
#         p_list.append(p1.text)
#         r_list.append(r1.text)
#         v_list.append(v1.text)
#         a_list.append(a1.text)
#         f_list.append(f1.text)
#         l_list.append(l1.text)

# %% [markdown]
# p3 = {"Price":p_list, "Room":r_list, "View Size":v_list, "Age":a_list, "Floortype":f_list, "Location":l_list}
# df = pd.DataFrame(p3)
# df

# %% [markdown]
# df.info()

# %% [markdown]
# liste=[BeautifulSoup(requests.get("https://www.hepsiemlak.com/istanbul"+"-kiralik?page="+str(i)).text,"html.parser") for i in range(1,15)]

# %% [markdown]
# soups=[BeautifulSoup(requests.get("https://www.hepsiemlak.com" + link['href']).text, "html.parser") for soup in liste for link in soup.findAll('a', href=True) if ('kiralik' in link['href']) and (link['class']==['card-link'])]

# %% [markdown]
# df=pd.DataFrame()
# for soup in soups:
#     row={}
#     row['Fiyat']= soup.findAll('p',{"class":"fontRB fz24 price"})[0].text
#     for ul in soup.findAll("ul",{"class":"adv-info-list"}):
#         for i in range(len(ul.findAll('li'))):
#             row[ul.findAll('li')[i].findAll('span')[0].text]= ul.findAll('li')[i].findAll('span')[1].text
#     df = df.append(row, ignore_index=True)

# %% [markdown]
# df.to_csv("istanbul.csv", index=False)

# %% [markdown]
# df=pd.read_csv('istanbul2.csv')

# %% [markdown]
# df
