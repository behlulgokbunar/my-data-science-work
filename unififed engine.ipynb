# %%
pip install spark
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyspark
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys
from pyspark.sql import SparkSession

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable
spark = SparkSession.builder.getOrCreate()

# %%
# Out:
#   Input In [30]
#     val ssc = new StreamingContext(sc, Seconds(1))
#         ^
# SyntaxError: invalid syntax

# %%
from pyspark import SparkConf,SparkContext
import collections

sc=SparkContext()
rdd=sc.parallelize([4,5,2,2])

sq=rdd.map(lambda x:x*x)

print(sq.collect())

sc.stop()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Input In [29], in <cell line: 4>()
#       1 from pyspark import SparkConf,SparkContext
#       2 import collections
# ----> 4 sc=SparkContext()
#       5 rdd=sc.parallelize([4,5,2,2])
#       7 sq=rdd.map(lambda x:x*x)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pyspark\context.py:197, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls)
#     195 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     196 try:
# --> 197     self._do_init(
#     198         master,
#     199         appName,
#     200         sparkHome,
#     201         pyFiles,
#     202         environment,
#     203         batchSize,
#     204         serializer,
#     205         conf,
#     206         jsc,
# ...

# %%
sc.stop()

# %%
from pyspark import SparkConf,SparkContext
import collections

conf=SparkConf().setMaster('local').setAppName('RatingsHistogram')
sc=SparkContext(conf = conf)

lines=sc.textFile('spark/ml-100k/u.data')
ratings=lines.map(lambda x: x.split()[2])
result=ratings.countByValue()
sortedResults=collection.OrderedDict(sorted(result.items()))
for key, value in sortedResults.items():
    print('%s %i'%(key, value))
sc.stop()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Input In [32], in <cell line: 5>()
#       2 import collections
#       4 conf=SparkConf().setMaster('local').setAppName('RatingsHistogram')
# ----> 5 sc=SparkContext(conf = conf)
#       7 lines=sc.textFile('u.data')
#       8 ratings=lines.map(lambda x: x.split()[2])
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pyspark\context.py:197, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls)
#     195 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     196 try:
# --> 197     self._do_init(
#     198         master,
#     199         appName,
#     200         sparkHome,
#     201         pyFiles,
#     202         environment,
#     203         batchSize,
#     204         serializer,
# ...

# %%
from pyspark import SparkConf , SparkContext 
conf = SparkConf ( ) .setMaster ( " local " ) . setAppName ( " Friends ByAge " ) 
sc = SparkContext ( conf = conf ) 
def parseline ( line ) : 
    fields = line.split ( ' , ' ) 
    age = int ( fields [ 2 ] ) 
    numFriends = int ( fields [ 3 ] ) 
    return ( age , numFriends )
lines = sc.textFile ( " spark / fakefriends.csv " ) 
rdd=lines.map ( parseline ) 
totalsByAge = rdd.mapValues ( lambda x : ( x , 1 ) ) . reduceByKey ( lambda x , y : ( x [ 0 ] + y [ e ] , x [ 1 ] + y [ 1 ] ) ) 
averagesByAge = totalsByAge.mapValues ( lambda x : int ( x [ 0 ] / x [ 1 ] ) ) 
results = averagesByAge.collect ( ) 
for result in results : 
    print ( result )
sc.stop()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Input In [35], in <cell line: 3>()
#       1 from pyspark import SparkConf , SparkContext
#       2 conf = SparkConf ( ) .setMaster ( " local " ) . setAppName ( " Friends ByAge " )
# ----> 3 sc = SparkContext ( conf = conf )
#       4 def parseline ( line ) :
#       5     fields = line.split ( ' , ' )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pyspark\context.py:197, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls)
#     195 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     196 try:
# --> 197     self._do_init(
#     198         master,
#     199         appName,
#     200         sparkHome,
#     201         pyFiles,
#     202         environment,
#     203         batchSize,
# ...

# %%
from pyspark import SparkConf , SparkContext 
conf = SparkConf ( ) .setMaster ( " local " ) . setAppName ( " MinTemperatures " ) 
sc = SparkContext ( conf = conf ) 
def parseLine ( line ) : 
    fields line.split ( ' , ' ) 
    stationID = fields [ 0 ] 
    entryType = fields [ 2 ] 
    temperature = float ( fields [ 3 ] ) * 0.1 * ( 9.0 / 5.0 ) + 32.0 
    return ( stationID , entryType , temperature ) 
lines = sc.textFile ( " spark / 1800.csv " ) 
parsed Lines = lines.map ( parseLine ) 
minTemps parsed Lines.filter ( lambda x : " MIN " in x [ 1 ] ) 
station Temps = minTemps.map ( lambda x : ( x [ 0 ] , * [ 2 ] ) ) 
minTemps = station Temps . reduceByKey ( lambda x , y : min ( x , y ) ) 
results = minTemps.collect ( ) ; 
for result in results : 
    print ( result [ 0 ] + " \ t { : . 2f } F " . format ( result [ 1 ] ) ) 
    sc.stop ( )
# Out:
#   Input In [36]
#     fields line.split ( ' , ' )
#            ^
# SyntaxError: invalid syntax

# %%
from pyspark import SparkConf , SparkContext 
conf = SparkConf ( ) .setMaster ( " local " ) . setAppName ( " WordCount " )  
sc = SparkContext ( conf = conf )
input = sc.textFile ( " spark / book.txt " ) 
words = input.flatMap ( lambda x : x.split ( ) ) 
wordCounts = words.countByValue ( ) 

for word , count in wordCounts.items ( ) : 
    cleanWord = word . encode ( ' ascii ' , ' ignore ' ) 
    if ( cleanWord ) : 
        print ( cleanWord.decode ( ) + " " + str ( count ) ) 
sc.stop ( )
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Input In [37], in <cell line: 3>()
#       1 from pyspark import SparkConf , SparkContext
#       2 conf = SparkConf ( ) .setMaster ( " local " ) . setAppName ( " WordCount " )
# ----> 3 sc = SparkContext ( conf = conf )
#       4 input = sc.textFile ( " spark / book.txt " )
#       5 words = input.flatMap ( lambda x : x.split ( ) )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pyspark\context.py:197, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls)
#     195 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     196 try:
# --> 197     self._do_init(
#     198         master,
#     199         appName,
#     200         sparkHome,
#     201         pyFiles,
#     202         environment,
# ...
